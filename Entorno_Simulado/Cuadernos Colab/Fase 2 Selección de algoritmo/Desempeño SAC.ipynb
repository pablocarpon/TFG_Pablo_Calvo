# %%
# !pip install gymnasium
# !pip install git+https://github.com/pablocarpon/rSoccer.git
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Collecting git+https://github.com/pablocarpon/rSoccer.git
#   Cloning https://github.com/pablocarpon/rSoccer.git to /tmp/pip-req-build-xg3ap222
#   Running command git clone --filter=blob:none --quiet https://github.com/pablocarpon/rSoccer.git /tmp/pip-req-build-xg3ap222
#   Resolved https://github.com/pablocarpon/rSoccer.git to commit bf8b88bb228835b67aba3f3b967624a12aba226a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (0.29.1)
# Requirement already satisfied: rc-robosim>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (1.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (2.5.2)
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (3.20.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (0.0.4)

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 stable_baselines3-2.3.2

# %%
import rsoccer_gym
import gymnasium as gym

import stable_baselines3
from stable_baselines3 import SAC
from stable_baselines3.common.logger import configure
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.noise import OrnsteinUhlenbeckActionNoise

import numpy as np

# %%
# Create the environment and initialize it with reset method
env = gym.make('VSS1vs1-v0')
env.reset()

# Set up logger to store episode mean reward value in a csv file
csv_path = "./sb3_log"
custom_logger = configure(
    folder=csv_path,
    format_strings=["stdout", "csv"]
)

# Create a callback to evaluate the agent every eval_freq steps
eval_env = gym.make('VSS1vs1-v0')
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./eval_logs",
    log_path="./eval_logs",
    n_eval_episodes=10,
    eval_freq=100_000,
    deterministic=True,
    render=False,
    verbose=1
)

# Create an action noise object and add it to the model
n_actions = env.action_space.shape[-1]
action_noise = OrnsteinUhlenbeckActionNoise(
    mean=np.zeros(n_actions),
    sigma=0.1 * np.ones(n_actions)
)

# Create the model, set the new logger and train
model = SAC(
    "MlpPolicy",
    env,
    learning_rate=1.25e-3,
    action_noise=action_noise,
    verbose=1
)
model.set_logger(custom_logger)
model.learn(total_timesteps=1_000_000, callback=eval_callback)
# Out:
# Environment initialized
# Logging to ./sb3_log
# Environment initialized
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -2.59    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 86       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -4.26    |
# |    critic_loss     | 0.0175   |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -0.996   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 86       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 8575     |
# | train/             |          |
# |    actor_loss      | -5.83    |
# |    critic_loss     | 0.059    |
# |    ent_coef        | 0.0125   |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 8474     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 980      |
# |    ep_rew_mean     | 3.14     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 86       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 11765    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.276    |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | 0.0529   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 11664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 990      |
# |    ep_rew_mean     | -4.43    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 87       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 15839    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -0.528   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 15738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -5.71    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 87       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 20639    |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.58     |
# |    ent_coef        | 0.0501   |
# |    ent_coef_loss   | 0.416    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 20538    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | -5.55    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 87       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 25439    |
# | train/             |          |
# |    actor_loss      | -41.1    |
# |    critic_loss     | 8.09     |
# |    ent_coef        | 0.0654   |
# |    ent_coef_loss   | 0.0553   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 25338    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | -8.09    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 87       |
# |    time_elapsed    | 346      |
# |    total_timesteps | 30239    |
# | train/             |          |
# |    actor_loss      | -45.8    |
# |    critic_loss     | 5.96     |
# |    ent_coef        | 0.0662   |
# |    ent_coef_loss   | -0.56    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 30138    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | -7.07    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 86       |
# |    time_elapsed    | 403      |
# |    total_timesteps | 35039    |
# | train/             |          |
# |    actor_loss      | -49.6    |
# |    critic_loss     | 3.73     |
# |    ent_coef        | 0.0653   |
# |    ent_coef_loss   | 0.0396   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 34938    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -7.92    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 86       |
# |    time_elapsed    | 459      |
# |    total_timesteps | 39839    |
# | train/             |          |
# |    actor_loss      | -51.8    |
# |    critic_loss     | 4.85     |
# |    ent_coef        | 0.0575   |
# |    ent_coef_loss   | 0.114    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 39738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -10.7    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 86       |
# |    time_elapsed    | 515      |
# |    total_timesteps | 44639    |
# | train/             |          |
# |    actor_loss      | -41.1    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.0376   |
# |    ent_coef_loss   | 0.316    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 44538    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -10.1    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 86       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 48881    |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.246    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 48780    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -10.7    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 86       |
# |    time_elapsed    | 621      |
# |    total_timesteps | 53681    |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 53580    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -10.9    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 86       |
# |    time_elapsed    | 677      |
# |    total_timesteps | 58481    |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.0246   |
# |    ent_coef_loss   | -0.662   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 58380    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -9.63    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 86       |
# |    time_elapsed    | 724      |
# |    total_timesteps | 62529    |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | 0.0441   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 62428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -9.35    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 86       |
# |    time_elapsed    | 780      |
# |    total_timesteps | 67329    |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 1.84     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 67228    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -9.86    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 86       |
# |    time_elapsed    | 832      |
# |    total_timesteps | 71780    |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 0.694    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.09    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 71679    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -9.11    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 86       |
# |    time_elapsed    | 888      |
# |    total_timesteps | 76580    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.845    |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | 0.219    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 76479    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -7.98    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 86       |
# |    time_elapsed    | 943      |
# |    total_timesteps | 81380    |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.519    |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | -0.191   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 81279    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -9.16    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 86       |
# |    time_elapsed    | 986      |
# |    total_timesteps | 85113    |
# | train/             |          |
# |    actor_loss      | -9.59    |
# |    critic_loss     | 0.518    |
# |    ent_coef        | 0.0134   |
# |    ent_coef_loss   | 1.31     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 85012    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 86       |
# |    time_elapsed    | 1029     |
# |    total_timesteps | 88825    |
# | train/             |          |
# |    actor_loss      | -7.38    |
# |    critic_loss     | 0.76     |
# |    ent_coef        | 0.0112   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 88724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -8.87    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 86       |
# |    time_elapsed    | 1074     |
# |    total_timesteps | 92623    |
# | train/             |          |
# |    actor_loss      | -5.44    |
# |    critic_loss     | 0.529    |
# |    ent_coef        | 0.0113   |
# |    ent_coef_loss   | -0.044   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 92522    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -8.56    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 86       |
# |    time_elapsed    | 1129     |
# |    total_timesteps | 97423    |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.46     |
# |    ent_coef        | 0.0106   |
# |    ent_coef_loss   | 0.341    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 97322    |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=100000, episode_reward=-3.23 +/- 15.22
# Episode length: 1200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.2e+03  |
# |    mean_reward     | -3.23    |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.365    |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | -0.487   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 99899    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -8.61    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 84       |
# |    time_elapsed    | 1193     |
# |    total_timesteps | 101290   |
# | train/             |          |
# |    actor_loss      | -1.43    |
# |    critic_loss     | 0.398    |
# |    ent_coef        | 0.00969  |
# |    ent_coef_loss   | -0.746   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 101189   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | -9.48    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 84       |
# |    time_elapsed    | 1236     |
# |    total_timesteps | 105004   |
# | train/             |          |
# |    actor_loss      | 0.247    |
# |    critic_loss     | 0.33     |
# |    ent_coef        | 0.0102   |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 104903   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -9.32    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 84       |
# |    time_elapsed    | 1292     |
# |    total_timesteps | 109804   |
# | train/             |          |
# |    actor_loss      | 1.15     |
# |    critic_loss     | 0.353    |
# |    ent_coef        | 0.0103   |
# |    ent_coef_loss   | 0.655    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 109703   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -9.46    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 84       |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 114511   |
# | train/             |          |
# |    actor_loss      | 2.29     |
# |    critic_loss     | 0.345    |
# |    ent_coef        | 0.00948  |
# |    ent_coef_loss   | -0.345   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 114410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -9.77    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 84       |
# |    time_elapsed    | 1396     |
# |    total_timesteps | 118716   |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.555    |
# |    ent_coef        | 0.00889  |
# |    ent_coef_loss   | 0.744    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 118615   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -10.7    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 85       |
# |    time_elapsed    | 1452     |
# |    total_timesteps | 123516   |
# | train/             |          |
# |    actor_loss      | 3.3      |
# |    critic_loss     | 0.431    |
# |    ent_coef        | 0.00892  |
# |    ent_coef_loss   | -0.894   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 123415   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 85       |
# |    time_elapsed    | 1507     |
# |    total_timesteps | 128316   |
# | train/             |          |
# |    actor_loss      | 3.33     |
# |    critic_loss     | 0.316    |
# |    ent_coef        | 0.00894  |
# |    ent_coef_loss   | -0.595   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 128215   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -8.18    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 85       |
# |    time_elapsed    | 1562     |
# |    total_timesteps | 133116   |
# | train/             |          |
# |    actor_loss      | 4.98     |
# |    critic_loss     | 0.354    |
# |    ent_coef        | 0.00811  |
# |    ent_coef_loss   | -0.159   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 133015   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -8.28    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 85       |
# |    time_elapsed    | 1617     |
# |    total_timesteps | 137916   |
# | train/             |          |
# |    actor_loss      | 5.84     |
# |    critic_loss     | 0.551    |
# |    ent_coef        | 0.00866  |
# |    ent_coef_loss   | 0.688    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 137815   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -7.28    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 85       |
# |    time_elapsed    | 1661     |
# |    total_timesteps | 141764   |
# | train/             |          |
# |    actor_loss      | 5.79     |
# |    critic_loss     | 0.337    |
# |    ent_coef        | 0.00876  |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 141663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -7.05    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 85       |
# |    time_elapsed    | 1716     |
# |    total_timesteps | 146564   |
# | train/             |          |
# |    actor_loss      | 6.39     |
# |    critic_loss     | 0.281    |
# |    ent_coef        | 0.00829  |
# |    ent_coef_loss   | 0.103    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 146463   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -7.94    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 85       |
# |    time_elapsed    | 1771     |
# |    total_timesteps | 151291   |
# | train/             |          |
# |    actor_loss      | 6.11     |
# |    critic_loss     | 0.396    |
# |    ent_coef        | 0.00861  |
# |    ent_coef_loss   | 1.4      |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 151190   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -6.9     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 85       |
# |    time_elapsed    | 1813     |
# |    total_timesteps | 154973   |
# | train/             |          |
# |    actor_loss      | 4.81     |
# |    critic_loss     | 0.363    |
# |    ent_coef        | 0.00843  |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 154872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -4.76    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 85       |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 159427   |
# | train/             |          |
# |    actor_loss      | 5.23     |
# |    critic_loss     | 0.304    |
# |    ent_coef        | 0.00841  |
# |    ent_coef_loss   | -0.581   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 159326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -2.97    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 85       |
# |    time_elapsed    | 1919     |
# |    total_timesteps | 164154   |
# | train/             |          |
# |    actor_loss      | 5.42     |
# |    critic_loss     | 0.255    |
# |    ent_coef        | 0.00783  |
# |    ent_coef_loss   | -0.314   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 164053   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -1.26    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 85       |
# |    time_elapsed    | 1974     |
# |    total_timesteps | 168954   |
# | train/             |          |
# |    actor_loss      | 7.08     |
# |    critic_loss     | 0.426    |
# |    ent_coef        | 0.00737  |
# |    ent_coef_loss   | 0.401    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 168853   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -1.75    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 85       |
# |    time_elapsed    | 2026     |
# |    total_timesteps | 173438   |
# | train/             |          |
# |    actor_loss      | 5.78     |
# |    critic_loss     | 0.289    |
# |    ent_coef        | 0.00788  |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 173337   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -1.45    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 85       |
# |    time_elapsed    | 2081     |
# |    total_timesteps | 178238   |
# | train/             |          |
# |    actor_loss      | 7.17     |
# |    critic_loss     | 0.39     |
# |    ent_coef        | 0.00726  |
# |    ent_coef_loss   | -0.55    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 178137   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -0.961   |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 85       |
# |    time_elapsed    | 2136     |
# |    total_timesteps | 183038   |
# | train/             |          |
# |    actor_loss      | 7.59     |
# |    critic_loss     | 0.423    |
# |    ent_coef        | 0.00756  |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 182937   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -0.209   |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 85       |
# |    time_elapsed    | 2191     |
# |    total_timesteps | 187838   |
# | train/             |          |
# |    actor_loss      | 7.22     |
# |    critic_loss     | 0.274    |
# |    ent_coef        | 0.00752  |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 187737   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -0.959   |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 85       |
# |    time_elapsed    | 2246     |
# |    total_timesteps | 192638   |
# | train/             |          |
# |    actor_loss      | 7.08     |
# |    critic_loss     | 0.281    |
# |    ent_coef        | 0.00704  |
# |    ent_coef_loss   | 0.285    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 192537   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 0.41     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 85       |
# |    time_elapsed    | 2301     |
# |    total_timesteps | 197438   |
# | train/             |          |
# |    actor_loss      | 7.01     |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.00686  |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 197337   |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=26.36 +/- 40.99
# Episode length: 1175.50 +/- 73.50
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.18e+03 |
# |    mean_reward     | 26.4     |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 7.51     |
# |    critic_loss     | 0.312    |
# |    ent_coef        | 0.00683  |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 199899   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 1.16     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 85       |
# |    time_elapsed    | 2376     |
# |    total_timesteps | 202238   |
# | train/             |          |
# |    actor_loss      | 7        |
# |    critic_loss     | 0.774    |
# |    ent_coef        | 0.00668  |
# |    ent_coef_loss   | 0.254    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 202137   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 1.25     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 85       |
# |    time_elapsed    | 2419     |
# |    total_timesteps | 206042   |
# | train/             |          |
# |    actor_loss      | 7.92     |
# |    critic_loss     | 0.313    |
# |    ent_coef        | 0.00689  |
# |    ent_coef_loss   | 0.44     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 205941   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 1.45     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 85       |
# |    time_elapsed    | 2475     |
# |    total_timesteps | 210842   |
# | train/             |          |
# |    actor_loss      | 8.06     |
# |    critic_loss     | 0.339    |
# |    ent_coef        | 0.00701  |
# |    ent_coef_loss   | -0.0268  |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 210741   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 2.35     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 85       |
# |    time_elapsed    | 2530     |
# |    total_timesteps | 215642   |
# | train/             |          |
# |    actor_loss      | 7.92     |
# |    critic_loss     | 0.305    |
# |    ent_coef        | 0.00727  |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 215541   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 4.98     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 85       |
# |    time_elapsed    | 2561     |
# |    total_timesteps | 218352   |
# | train/             |          |
# |    actor_loss      | 7.99     |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.0069   |
# |    ent_coef_loss   | 0.755    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 218251   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 5.96     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 85       |
# |    time_elapsed    | 2617     |
# |    total_timesteps | 223152   |
# | train/             |          |
# |    actor_loss      | 8.16     |
# |    critic_loss     | 0.326    |
# |    ent_coef        | 0.00715  |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 223051   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 5.94     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 85       |
# |    time_elapsed    | 2669     |
# |    total_timesteps | 227690   |
# | train/             |          |
# |    actor_loss      | 8.65     |
# |    critic_loss     | 0.276    |
# |    ent_coef        | 0.00681  |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 227589   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 6.06     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 85       |
# |    time_elapsed    | 2706     |
# |    total_timesteps | 230936   |
# | train/             |          |
# |    actor_loss      | 8.13     |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.00738  |
# |    ent_coef_loss   | -0.477   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 230835   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 6.66     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 85       |
# |    time_elapsed    | 2755     |
# |    total_timesteps | 235156   |
# | train/             |          |
# |    actor_loss      | 8.41     |
# |    critic_loss     | 0.268    |
# |    ent_coef        | 0.00669  |
# |    ent_coef_loss   | 0.783    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 235055   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 7.17     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 85       |
# |    time_elapsed    | 2810     |
# |    total_timesteps | 239956   |
# | train/             |          |
# |    actor_loss      | 9.01     |
# |    critic_loss     | 0.373    |
# |    ent_coef        | 0.00685  |
# |    ent_coef_loss   | 0.0261   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 239855   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.73     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 85       |
# |    time_elapsed    | 2865     |
# |    total_timesteps | 244756   |
# | train/             |          |
# |    actor_loss      | 10.3     |
# |    critic_loss     | 0.454    |
# |    ent_coef        | 0.00699  |
# |    ent_coef_loss   | 0.777    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 244655   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 6.22     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 85       |
# |    time_elapsed    | 2920     |
# |    total_timesteps | 249556   |
# | train/             |          |
# |    actor_loss      | 9.83     |
# |    critic_loss     | 0.492    |
# |    ent_coef        | 0.00728  |
# |    ent_coef_loss   | 0.875    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 249455   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.72     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 85       |
# |    time_elapsed    | 2964     |
# |    total_timesteps | 253337   |
# | train/             |          |
# |    actor_loss      | 9.67     |
# |    critic_loss     | 0.348    |
# |    ent_coef        | 0.00694  |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 253236   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 5.72     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 85       |
# |    time_elapsed    | 3016     |
# |    total_timesteps | 257858   |
# | train/             |          |
# |    actor_loss      | 9.78     |
# |    critic_loss     | 0.343    |
# |    ent_coef        | 0.00642  |
# |    ent_coef_loss   | 0.586    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 257757   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 9.36     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 85       |
# |    time_elapsed    | 3060     |
# |    total_timesteps | 261721   |
# | train/             |          |
# |    actor_loss      | 10.1     |
# |    critic_loss     | 0.375    |
# |    ent_coef        | 0.0068   |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 261620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 9.71     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 85       |
# |    time_elapsed    | 3115     |
# |    total_timesteps | 266521   |
# | train/             |          |
# |    actor_loss      | 10.4     |
# |    critic_loss     | 0.387    |
# |    ent_coef        | 0.00656  |
# |    ent_coef_loss   | -0.591   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 266420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 7.56     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 85       |
# |    time_elapsed    | 3170     |
# |    total_timesteps | 271321   |
# | train/             |          |
# |    actor_loss      | 10.4     |
# |    critic_loss     | 0.294    |
# |    ent_coef        | 0.0066   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 271220   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 7.32     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 85       |
# |    time_elapsed    | 3225     |
# |    total_timesteps | 276121   |
# | train/             |          |
# |    actor_loss      | 10.9     |
# |    critic_loss     | 0.395    |
# |    ent_coef        | 0.00672  |
# |    ent_coef_loss   | -0.887   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 276020   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 6.57     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 85       |
# |    time_elapsed    | 3280     |
# |    total_timesteps | 280921   |
# | train/             |          |
# |    actor_loss      | 11.1     |
# |    critic_loss     | 0.341    |
# |    ent_coef        | 0.00685  |
# |    ent_coef_loss   | -0.0148  |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 280820   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.94     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 85       |
# |    time_elapsed    | 3336     |
# |    total_timesteps | 285721   |
# | train/             |          |
# |    actor_loss      | 11.1     |
# |    critic_loss     | 0.45     |
# |    ent_coef        | 0.0067   |
# |    ent_coef_loss   | 0.418    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 285620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.22     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 85       |
# |    time_elapsed    | 3391     |
# |    total_timesteps | 290521   |
# | train/             |          |
# |    actor_loss      | 10.8     |
# |    critic_loss     | 0.387    |
# |    ent_coef        | 0.00641  |
# |    ent_coef_loss   | 0.22     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 290420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.43     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 85       |
# |    time_elapsed    | 3447     |
# |    total_timesteps | 295321   |
# | train/             |          |
# |    actor_loss      | 10.9     |
# |    critic_loss     | 0.488    |
# |    ent_coef        | 0.00592  |
# |    ent_coef_loss   | 0.139    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 295220   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 5.82     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 85       |
# |    time_elapsed    | 3487     |
# |    total_timesteps | 298822   |
# | train/             |          |
# |    actor_loss      | 11       |
# |    critic_loss     | 0.347    |
# |    ent_coef        | 0.00642  |
# |    ent_coef_loss   | -0.428   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 298721   |
# ---------------------------------
# Eval num_timesteps=300000, episode_reward=-2.23 +/- 17.86
# Episode length: 1146.70 +/- 124.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.15e+03 |
# |    mean_reward     | -2.23    |
# | time/              |          |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | 11.5     |
# |    critic_loss     | 0.369    |
# |    ent_coef        | 0.00607  |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 299899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 5.98     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 85       |
# |    time_elapsed    | 3562     |
# |    total_timesteps | 303622   |
# | train/             |          |
# |    actor_loss      | 11.8     |
# |    critic_loss     | 0.402    |
# |    ent_coef        | 0.00638  |
# |    ent_coef_loss   | 0.504    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 303521   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 4.74     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 85       |
# |    time_elapsed    | 3617     |
# |    total_timesteps | 308422   |
# | train/             |          |
# |    actor_loss      | 11.6     |
# |    critic_loss     | 0.428    |
# |    ent_coef        | 0.006    |
# |    ent_coef_loss   | -0.0868  |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 308321   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 5.51     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 85       |
# |    time_elapsed    | 3668     |
# |    total_timesteps | 312904   |
# | train/             |          |
# |    actor_loss      | 11.6     |
# |    critic_loss     | 0.615    |
# |    ent_coef        | 0.00665  |
# |    ent_coef_loss   | 0.0177   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 312803   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 5.04     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 85       |
# |    time_elapsed    | 3717     |
# |    total_timesteps | 317116   |
# | train/             |          |
# |    actor_loss      | 11.8     |
# |    critic_loss     | 0.335    |
# |    ent_coef        | 0.00643  |
# |    ent_coef_loss   | -0.11    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 317015   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 85       |
# |    time_elapsed    | 3773     |
# |    total_timesteps | 321916   |
# | train/             |          |
# |    actor_loss      | 12.2     |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.00637  |
# |    ent_coef_loss   | -1.4     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 321815   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 4.43     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 85       |
# |    time_elapsed    | 3828     |
# |    total_timesteps | 326716   |
# | train/             |          |
# |    actor_loss      | 12.5     |
# |    critic_loss     | 0.37     |
# |    ent_coef        | 0.00608  |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 326615   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 3.34     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 85       |
# |    time_elapsed    | 3883     |
# |    total_timesteps | 331516   |
# | train/             |          |
# |    actor_loss      | 12       |
# |    critic_loss     | 0.352    |
# |    ent_coef        | 0.00596  |
# |    ent_coef_loss   | 0.541    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 331415   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 2.22     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 85       |
# |    time_elapsed    | 3925     |
# |    total_timesteps | 335150   |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.462    |
# |    ent_coef        | 0.00604  |
# |    ent_coef_loss   | 0.442    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 335049   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 3.65     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 85       |
# |    time_elapsed    | 3981     |
# |    total_timesteps | 339950   |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.00609  |
# |    ent_coef_loss   | -0.0786  |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 339849   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 4.43     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 85       |
# |    time_elapsed    | 4036     |
# |    total_timesteps | 344750   |
# | train/             |          |
# |    actor_loss      | 12.8     |
# |    critic_loss     | 0.367    |
# |    ent_coef        | 0.00569  |
# |    ent_coef_loss   | -0.677   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 344649   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 4.34     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 85       |
# |    time_elapsed    | 4080     |
# |    total_timesteps | 348523   |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.376    |
# |    ent_coef        | 0.00548  |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 348422   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 4.58     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 85       |
# |    time_elapsed    | 4135     |
# |    total_timesteps | 353323   |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 0.361    |
# |    ent_coef        | 0.00553  |
# |    ent_coef_loss   | -0.0631  |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 353222   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# ...
# |    episodes        | 796      |
# |    fps             | 85       |
# |    time_elapsed    | 10391    |
# |    total_timesteps | 889685   |
# | train/             |          |
# |    actor_loss      | 13.2     |
# |    critic_loss     | 0.326    |
# |    ent_coef        | 0.00463  |
# |    ent_coef_loss   | -1.84    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 889584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 5.99     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 85       |
# |    time_elapsed    | 10434    |
# |    total_timesteps | 893431   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.467    |
# |    ent_coef        | 0.00456  |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 893330   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 6.71     |
# | time/              |          |
# |    episodes        | 804      |
# |    fps             | 85       |
# |    time_elapsed    | 10489    |
# |    total_timesteps | 898231   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.00466  |
# |    ent_coef_loss   | 0.732    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 898130   |
# ---------------------------------
# Eval num_timesteps=900000, episode_reward=8.77 +/- 28.78
# Episode length: 1200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.2e+03  |
# |    mean_reward     | 8.77     |
# | time/              |          |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.28     |
# |    ent_coef        | 0.00423  |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 899899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 7.01     |
# | time/              |          |
# |    episodes        | 808      |
# |    fps             | 85       |
# |    time_elapsed    | 10549    |
# |    total_timesteps | 901739   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.355    |
# |    ent_coef        | 0.0049   |
# |    ent_coef_loss   | 2.06     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 901638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 6.37     |
# | time/              |          |
# |    episodes        | 812      |
# |    fps             | 85       |
# |    time_elapsed    | 10581    |
# |    total_timesteps | 904537   |
# | train/             |          |
# |    actor_loss      | 13.4     |
# |    critic_loss     | 0.379    |
# |    ent_coef        | 0.00434  |
# |    ent_coef_loss   | 0.945    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 904436   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 7.76     |
# | time/              |          |
# |    episodes        | 816      |
# |    fps             | 85       |
# |    time_elapsed    | 10631    |
# |    total_timesteps | 908727   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.333    |
# |    ent_coef        | 0.00431  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 908626   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 7.04     |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 85       |
# |    time_elapsed    | 10674    |
# |    total_timesteps | 912487   |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 0.72     |
# |    ent_coef        | 0.00476  |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 912386   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 5.63     |
# | time/              |          |
# |    episodes        | 824      |
# |    fps             | 85       |
# |    time_elapsed    | 10730    |
# |    total_timesteps | 917287   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.346    |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 917186   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 6.09     |
# | time/              |          |
# |    episodes        | 828      |
# |    fps             | 85       |
# |    time_elapsed    | 10785    |
# |    total_timesteps | 922087   |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.277    |
# |    ent_coef        | 0.00442  |
# |    ent_coef_loss   | -0.989   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 921986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 5.03     |
# | time/              |          |
# |    episodes        | 832      |
# |    fps             | 85       |
# |    time_elapsed    | 10840    |
# |    total_timesteps | 926887   |
# | train/             |          |
# |    actor_loss      | 13.5     |
# |    critic_loss     | 0.674    |
# |    ent_coef        | 0.00449  |
# |    ent_coef_loss   | -0.966   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 926786   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 4.88     |
# | time/              |          |
# |    episodes        | 836      |
# |    fps             | 85       |
# |    time_elapsed    | 10896    |
# |    total_timesteps | 931687   |
# | train/             |          |
# |    actor_loss      | 13.2     |
# |    critic_loss     | 0.288    |
# |    ent_coef        | 0.00455  |
# |    ent_coef_loss   | 0.971    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 931586   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 3.53     |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 85       |
# |    time_elapsed    | 10952    |
# |    total_timesteps | 936487   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.329    |
# |    ent_coef        | 0.00467  |
# |    ent_coef_loss   | 0.409    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 936386   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 2.97     |
# | time/              |          |
# |    episodes        | 844      |
# |    fps             | 85       |
# |    time_elapsed    | 11008    |
# |    total_timesteps | 941287   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.00446  |
# |    ent_coef_loss   | 0.475    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 941186   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 2.62     |
# | time/              |          |
# |    episodes        | 848      |
# |    fps             | 85       |
# |    time_elapsed    | 11064    |
# |    total_timesteps | 946087   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.626    |
# |    ent_coef        | 0.00457  |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 945986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 2.79     |
# | time/              |          |
# |    episodes        | 852      |
# |    fps             | 85       |
# |    time_elapsed    | 11120    |
# |    total_timesteps | 950887   |
# | train/             |          |
# |    actor_loss      | 13.4     |
# |    critic_loss     | 0.406    |
# |    ent_coef        | 0.00405  |
# |    ent_coef_loss   | 0.0951   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 950786   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 2.03     |
# | time/              |          |
# |    episodes        | 856      |
# |    fps             | 85       |
# |    time_elapsed    | 11166    |
# |    total_timesteps | 954872   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.329    |
# |    ent_coef        | 0.00463  |
# |    ent_coef_loss   | 0.328    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 954771   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 2.25     |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 85       |
# |    time_elapsed    | 11223    |
# |    total_timesteps | 959672   |
# | train/             |          |
# |    actor_loss      | 13.2     |
# |    critic_loss     | 0.244    |
# |    ent_coef        | 0.00424  |
# |    ent_coef_loss   | 0.0113   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 959571   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 1.92     |
# | time/              |          |
# |    episodes        | 864      |
# |    fps             | 85       |
# |    time_elapsed    | 11278    |
# |    total_timesteps | 964472   |
# | train/             |          |
# |    actor_loss      | 13.4     |
# |    critic_loss     | 0.454    |
# |    ent_coef        | 0.00439  |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 964371   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 1.85     |
# | time/              |          |
# |    episodes        | 868      |
# |    fps             | 85       |
# |    time_elapsed    | 11331    |
# |    total_timesteps | 968995   |
# | train/             |          |
# |    actor_loss      | 12.8     |
# |    critic_loss     | 0.245    |
# |    ent_coef        | 0.00458  |
# |    ent_coef_loss   | 1.69     |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 968894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 2.26     |
# | time/              |          |
# |    episodes        | 872      |
# |    fps             | 85       |
# |    time_elapsed    | 11386    |
# |    total_timesteps | 973795   |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 0.391    |
# |    ent_coef        | 0.0042   |
# |    ent_coef_loss   | 0.723    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 973694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 2.44     |
# | time/              |          |
# |    episodes        | 876      |
# |    fps             | 85       |
# |    time_elapsed    | 11440    |
# |    total_timesteps | 978595   |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.00421  |
# |    ent_coef_loss   | 0.455    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 978494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 3.04     |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 85       |
# |    time_elapsed    | 11496    |
# |    total_timesteps | 983395   |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.487    |
# |    ent_coef        | 0.0045   |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 983294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 2.09     |
# | time/              |          |
# |    episodes        | 884      |
# |    fps             | 85       |
# |    time_elapsed    | 11551    |
# |    total_timesteps | 988195   |
# | train/             |          |
# |    actor_loss      | 12.8     |
# |    critic_loss     | 0.356    |
# |    ent_coef        | 0.00418  |
# |    ent_coef_loss   | 0.909    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 988094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 2.09     |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 85       |
# |    time_elapsed    | 11594    |
# |    total_timesteps | 991869   |
# | train/             |          |
# |    actor_loss      | 12.7     |
# |    critic_loss     | 0.263    |
# |    ent_coef        | 0.00425  |
# |    ent_coef_loss   | 0.183    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 991768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 2.29     |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 85       |
# |    time_elapsed    | 11644    |
# |    total_timesteps | 996241   |
# | train/             |          |
# |    actor_loss      | 12.8     |
# |    critic_loss     | 0.335    |
# |    ent_coef        | 0.00438  |
# |    ent_coef_loss   | -0.442   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 996140   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 3.12     |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 85       |
# |    time_elapsed    | 11686    |
# |    total_timesteps | 999878   |
# | train/             |          |
# |    actor_loss      | 12.6     |
# |    critic_loss     | 0.443    |
# |    ent_coef        | 0.00426  |
# |    ent_coef_loss   | 0.366    |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 999777   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-1.14 +/- 22.94
# Episode length: 1047.10 +/- 323.72
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.05e+03 |
# |    mean_reward     | -1.14    |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 12.3     |
# |    critic_loss     | 0.446    |
# |    ent_coef        | 0.00412  |
# |    ent_coef_loss   | -0.541   |
# |    learning_rate   | 0.00125  |
# |    n_updates       | 999899   |
# ---------------------------------
