# %% [markdown]
# # Búsquea Learning Rate para PPO
# En este cuaderno se va a realizar la experimentación necesaria para obtener el valor óptimo del hiperparámetro *learning rate* para el algoritmo PPO(Proximal Policy Optimization).
#
# Esta búsqueda del valor óptimo se va a hacer a través de una técnica conocida como *learning rate schedule*, la cual va variando el valor de la tasa de aprendizaje a lo largo del entrenamiento para observar las recompensas que se van obteniendo para cada valor.

# %% [markdown]
# ## Instalar las librerías del entorno
# En primer lugar se hace una descarga e instalación de las librerías que se van a usar para modelar el entorno en el que se va a entrenar al agente.
#
# La primera de las librerías corresponde a un repositorio propio que se ha originado a través de un fork a otro repostorio en el que se había creado un *framework* orientado principalmente al desarrollo de entornos similares a los que se presentan en la Robocup, el cual es uno de los campeonato de fútbol robótico más conocidos a nivel mundial. Lo bueno de dicho repositorio es que los entornos que ya tiene implementados son de robots móviles y en especial los entornos VSS están formados por robots con unas carácterísticas hardware ciertamente similares a los turtlebots.
#
# La segunda librería es *gymnasium* y es un estandar dentro de la programación de entornos orientados al aprendizaje por refuerzo.

# %%
# !pip install gymnasium
# !pip install git+https://github.com/pablocarpon/rSoccer.git
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Collecting git+https://github.com/pablocarpon/rSoccer.git
#   Cloning https://github.com/pablocarpon/rSoccer.git to /tmp/pip-req-build-r__xc35i
#   Running command git clone --filter=blob:none --quiet https://github.com/pablocarpon/rSoccer.git /tmp/pip-req-build-r__xc35i
#   Resolved https://github.com/pablocarpon/rSoccer.git to commit bf8b88bb228835b67aba3f3b967624a12aba226a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (0.29.1)
# Requirement already satisfied: rc-robosim>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (1.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (2.5.2)
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (3.20.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (0.0.4)

# %% [markdown]
# ## Instalar las librerías del agente
# Tras instalar las librerías de Python que me van a ayudar a progamar el entorno, hago lo mismo con las que contienen algoritmos para regir el comportamiento del agente y optimizar su entrenamiento.
#
# En este caso estoy usando *stable_baselines3* que recoge varios algoritmos de aprendizaje por refuerzo escritos sobre la librería *pytorch*.
#
# La tercera línea de la celda inferior sirve para instalar también librerías como *tqdm* y *rich*, las cuales sirven para poder usar un *callback* que tiene *stable-baselines3* implementado con el fin de monitorizar el tiempo transcurrido durante el entrenamiento y el tiempo estimado que queda para finalizar el entrenamiento. Dicho *callback* recibe el nombre de *ProgressBarCallback*.

# %%
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.0+cpu)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)

# %% [markdown]
# ## Importar todas las librerías necesarias
# Tras la instalción se importan al cuaderno todos los módulos que voy a necesitar para el entrenamiento del modelo.

# %%
import rsoccer_gym
import gymnasium as gym

import stable_baselines3
from stable_baselines3 import PPO

# %% [markdown]
# # Entrenamiento del modelo
# En esta sección se va a proceder a entrenar el modelo con un learning rate asociado a una función que lo irá calculando en cada momento.
#
# Para esta experimentación se van a definir dos funciones de búsqueda del learning rate óptimo. Ambas funciones aceptan como parámetro el valor inicial de la tasa de aprendizaje, pero una de ellas irá aumentando el valor hasta 1 conforme pasa el tiempo y la otra lo irá reduciendo hasta 0.
#
# Con esto se pretende ver si los valores óptimos son capaces de converger en un punto o área.

# %%
# Number of times each experiment has to repeat to have a more reliable
# hyperparameter tuning
EX_LOOP = 3
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
## EXPERIMENT 1

def linear_schedule_down(initial_value: float):
    """
    Linear learning rate schedule. The learning rate value will decrease

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

for i in range(EX_LOOP):
  if i > 0:
    del env
    del model_down
  # Initial learning rate of 0.001
  env = gym.make('VSS1vs1-v0')
  csv_name = f"log{i}_PPO_down"
  env = stable_baselines3.common.monitor.Monitor(env,csv_name)
  env.reset()
  model_down = PPO("MlpPolicy", env, learning_rate=linear_schedule_down(0.01), verbose=1)
  model_down.learn(total_timesteps=500_000)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# |    loss                 | 0.0615      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00112     |
# |    std                  | 0.956       |
# |    value_loss           | 0.322       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -13.3      |
# | time/                   |            |
# |    fps                  | 562        |
# |    iterations           | 19         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04185939 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.384      |
# |    learning_rate        | 0.00926    |
# |    loss                 | 0.0254     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000937  |
# |    std                  | 0.92       |
# |    value_loss           | 0.559      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -12.8      |
# | time/                   |            |
# |    fps                  | 562        |
# |    iterations           | 20         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.05270084 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.366      |
# |    learning_rate        | 0.00922    |
# |    loss                 | 0.00263    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00179   |
# |    std                  | 0.972      |
# |    value_loss           | 0.314      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.6      |
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 21         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.05545269 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.00918    |
# |    loss                 | 0.0784     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.006      |
# |    std                  | 0.965      |
# |    value_loss           | 0.604      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 22          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.047004912 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.00914     |
# |    loss                 | 0.0298      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00604     |
# |    std                  | 0.959       |
# |    value_loss           | 0.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.3       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 23          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.059065767 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0091      |
# |    loss                 | 0.0416      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00601     |
# |    std                  | 0.971       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.2      |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 24         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.04448787 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.00906    |
# |    loss                 | 0.109      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.00975    |
# |    std                  | 0.957      |
# |    value_loss           | 0.496      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.4      |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 25         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04821358 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.78      |
# |    explained_variance   | 0.771      |
# |    learning_rate        | 0.00902    |
# |    loss                 | 0.00566    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0142     |
# |    std                  | 0.975      |
# |    value_loss           | 0.136      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -11.8       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 26          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.042793028 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.00898     |
# |    loss                 | 0.0586      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00462     |
# |    std                  | 0.972       |
# |    value_loss           | 0.153       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 27          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.050445415 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.00894     |
# |    loss                 | 0.0491      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.964       |
# |    value_loss           | 0.149       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -12.6       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 28          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.055568386 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.00889     |
# |    loss                 | 0.0387      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00498    |
# |    std                  | 0.972       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | -12.5      |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 29         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.06782177 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.529      |
# |    learning_rate        | 0.00885    |
# |    loss                 | 0.0634     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00833    |
# |    std                  | 1          |
# |    value_loss           | 0.117      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 30          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.060498476 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.00881     |
# |    loss                 | 0.0446      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000423   |
# |    std                  | 0.986       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.6      |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 31         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.06693045 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.162      |
# |    learning_rate        | 0.00877    |
# |    loss                 | -0.0181    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00307   |
# |    std                  | 0.94       |
# |    value_loss           | 0.414      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -11.6       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 32          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.051140357 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.00873     |
# |    loss                 | 0.0733      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00353    |
# |    std                  | 0.959       |
# |    value_loss           | 0.643       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.5      |
# | time/                   |            |
# |    fps                  | 557        |
# |    iterations           | 33         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.06907614 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.668      |
# |    learning_rate        | 0.00869    |
# |    loss                 | 0.0962     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.000297  |
# |    std                  | 0.969      |
# |    value_loss           | 0.586      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -11.8      |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 34         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.10379344 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.696      |
# |    learning_rate        | 0.00865    |
# |    loss                 | 0.068      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00858    |
# |    std                  | 0.988      |
# |    value_loss           | 0.225      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -12.2     |
# | time/                   |           |
# |    fps                  | 556       |
# |    iterations           | 35        |
# |    time_elapsed         | 128       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0607816 |
# |    clip_fraction        | 0.368     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.77     |
# |    explained_variance   | 0.779     |
# |    learning_rate        | 0.00861   |
# |    loss                 | 0.0416    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.00343   |
# |    std                  | 0.968     |
# |    value_loss           | 0.236     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.8      |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 36         |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.07384005 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.00857    |
# |    loss                 | 0.0414     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.00791    |
# |    std                  | 0.955      |
# |    value_loss           | 0.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 37          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.057849087 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00853     |
# |    loss                 | 0.118       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000295    |
# |    std                  | 0.924       |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -10.7       |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 38          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.047156207 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.00848     |
# |    loss                 | 0.228       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000928   |
# |    std                  | 0.928       |
# |    value_loss           | 0.841       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 39          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.044798534 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.00844     |
# |    loss                 | 0.0771      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00426    |
# |    std                  | 0.929       |
# |    value_loss           | 0.517       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | -9.98      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 40         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.09179327 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.715      |
# |    learning_rate        | 0.0084     |
# |    loss                 | 0.0762     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0164     |
# |    std                  | 0.93       |
# |    value_loss           | 0.276      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | -10.4      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 41         |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08116729 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | 0.735      |
# |    learning_rate        | 0.00836    |
# |    loss                 | 0.498      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00522    |
# |    std                  | 0.969      |
# |    value_loss           | 1.61       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | -10.5      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 42         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.08606493 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.701      |
# |    learning_rate        | 0.00832    |
# |    loss                 | 0.0436     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.00674    |
# |    std                  | 0.981      |
# |    value_loss           | 0.393      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.13e+03  |
# |    ep_rew_mean          | -10.7     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 43        |
# |    time_elapsed         | 158       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0707887 |
# |    clip_fraction        | 0.397     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.76     |
# |    explained_variance   | 0.803     |
# |    learning_rate        | 0.00828   |
# |    loss                 | 0.123     |
# |    n_updates            | 420       |
# |    policy_gradient_loss | 0.00991   |
# |    std                  | 0.957     |
# |    value_loss           | 0.511     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | -10.8      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 44         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.12007071 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | 0.705      |
# |    learning_rate        | 0.00824    |
# |    loss                 | 0.139      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00102    |
# |    std                  | 1          |
# |    value_loss           | 0.23       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.14e+03  |
# |    ep_rew_mean          | -11       |
# | time/                   |           |
# |    fps                  | 553       |
# |    iterations           | 45        |
# |    time_elapsed         | 166       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0819377 |
# |    clip_fraction        | 0.425     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.87     |
# |    explained_variance   | 0.722     |
# |    learning_rate        | 0.0082    |
# |    loss                 | 0.0487    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0.00451   |
# |    std                  | 1.02      |
# |    value_loss           | 0.352     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | -11        |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 46         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07085602 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.776      |
# |    learning_rate        | 0.00816    |
# |    loss                 | 0.175      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00621    |
# |    std                  | 1.03       |
# |    value_loss           | 0.617      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | -10.7      |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 47         |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.09437317 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.779      |
# |    learning_rate        | 0.00812    |
# |    loss                 | 0.158      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.00683    |
# |    std                  | 1.04       |
# |    value_loss           | 0.301      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | -11        |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 48         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.09768524 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.633      |
# |    learning_rate        | 0.00807    |
# |    loss                 | 0.0412     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.00859    |
# |    std                  | 1.05       |
# |    value_loss           | 0.561      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.14e+03   |
# |    ep_rew_mean          | -11.1      |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 49         |
# |    time_elapsed         | 181        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.09434628 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.645      |
# |    learning_rate        | 0.00803    |
# |    loss                 | 0.0874     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00591    |
# |    std                  | 1.05       |
# |    value_loss           | 0.274      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.14e+03  |
# |    ep_rew_mean          | -10.4     |
# | time/                   |           |
# |    fps                  | 552       |
# |    iterations           | 50        |
# |    time_elapsed         | 185       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.0939339 |
# |    clip_fraction        | 0.44      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.91     |
# |    explained_variance   | 0.573     |
# |    learning_rate        | 0.00799   |
# |    loss                 | 0.115     |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.00309  |
# |    std                  | 1.03      |
# |    value_loss           | 0.489     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 51          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.091803834 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.0852      |
# |    learning_rate        | 0.00795     |
# |    loss                 | 0.0542      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0021     |
# |    std                  | 1.05        |
# |    value_loss           | 0.407       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.7      |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 52         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.12810847 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.474      |
# |    learning_rate        | 0.00791    |
# |    loss                 | 0.0277     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.00295    |
# |    std                  | 1.06       |
# |    value_loss           | 0.246      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.6      |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 53         |
# |    time_elapsed         | 196        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.19670448 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.00787    |
# |    loss                 | 0.0972     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0124     |
# |    std                  | 1.05       |
# |    value_loss           | 0.215      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 54          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.121624365 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.00783     |
# |    loss                 | 0.0832      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 1.03        |
# |    value_loss           | 1.56        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -11.1     |
# | time/                   |           |
# |    fps                  | 550       |
# |    iterations           | 55        |
# |    time_elapsed         | 204       |
# |    total_timesteps      | 112640    |
# | train/                  |           |
# |    approx_kl            | 0.2881914 |
# |    clip_fraction        | 0.51      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.88     |
# |    explained_variance   | 0.725     |
# |    learning_rate        | 0.00779   |
# |    loss                 | 0.13      |
# |    n_updates            | 540       |
# |    policy_gradient_loss | 0.0338    |
# |    std                  | 1.01      |
# |    value_loss           | 0.526     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -11.3      |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 56         |
# |    time_elapsed         | 208        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.29553112 |
# |    clip_fraction        | 0.556      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.668      |
# |    learning_rate        | 0.00775    |
# |    loss                 | 0.0208     |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.00493    |
# |    std                  | 1.01       |
# |    value_loss           | 0.194      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -11        |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 57         |
# |    time_elapsed         | 211        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.21631378 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.00771    |
# |    loss                 | 0.0704     |
# |    n_updates            | 560        |
# |    policy_gradient_loss | 0.0207     |
# |    std                  | 1.02       |
# |    value_loss           | 0.308      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -11.9      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 58         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.23404981 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.546      |
# |    learning_rate        | 0.00767    |
# |    loss                 | -0.00889   |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.00796    |
# |    std                  | 1.03       |
# |    value_loss           | 0.588      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -11.5      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 59         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.18686613 |
# |    clip_fraction        | 0.555      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 0.00762    |
# |    loss                 | 0.057      |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.0135     |
# |    std                  | 1.06       |
# |    value_loss           | 0.171      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -11       |
# | time/                   |           |
# |    fps                  | 551       |
# |    iterations           | 60        |
# |    time_elapsed         | 222       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.1617077 |
# |    clip_fraction        | 0.532     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.94     |
# |    explained_variance   | 0.592     |
# |    learning_rate        | 0.00758   |
# |    loss                 | 0.0822    |
# |    n_updates            | 590       |
# |    policy_gradient_loss | 0.00168   |
# |    std                  | 1.04      |
# |    value_loss           | 0.237     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -11.3     |
# | time/                   |           |
# |    fps                  | 551       |
# |    iterations           | 61        |
# |    time_elapsed         | 226       |
# |    total_timesteps      | 124928    |
# | train/                  |           |
# |    approx_kl            | 0.2277584 |
# |    clip_fraction        | 0.56      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.91     |
# |    explained_variance   | 0.649     |
# |    learning_rate        | 0.00754   |
# |    loss                 | 0.0347    |
# |    n_updates            | 600       |
# |    policy_gradient_loss | 0.00468   |
# |    std                  | 1.02      |
# |    value_loss           | 0.303     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.9      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 62         |
# |    time_elapsed         | 230        |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.15414354 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.707      |
# |    learning_rate        | 0.0075     |
# |    loss                 | 0.0938     |
# |    n_updates            | 610        |
# |    policy_gradient_loss | 0.00593    |
# |    std                  | 1.02       |
# |    value_loss           | 0.323      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -10.7     |
# | time/                   |           |
# |    fps                  | 551       |
# |    iterations           | 63        |
# |    time_elapsed         | 233       |
# |    total_timesteps      | 129024    |
# | train/                  |           |
# |    approx_kl            | 0.2836775 |
# |    clip_fraction        | 0.546     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.87     |
# |    explained_variance   | 0.586     |
# |    learning_rate        | 0.00746   |
# |    loss                 | 0.343     |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.000213 |
# |    std                  | 1.02      |
# |    value_loss           | 0.813     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.6      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 64         |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.22268048 |
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.282      |
# |    learning_rate        | 0.00742    |
# |    loss                 | 0.0796     |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.00262   |
# |    std                  | 1.02       |
# |    value_loss           | 0.373      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.9      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 65         |
# |    time_elapsed         | 241        |
# |    total_timesteps      | 133120     |
# | train/                  |            |
# |    approx_kl            | 0.21990672 |
# |    clip_fraction        | 0.58       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.325      |
# |    learning_rate        | 0.00738    |
# |    loss                 | 0.0337     |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.00236    |
# |    std                  | 1.03       |
# |    value_loss           | 0.215      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.9      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 66         |
# |    time_elapsed         | 245        |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.23232196 |
# |    clip_fraction        | 0.557      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.00734    |
# |    loss                 | 0.012      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | 0.00407    |
# |    std                  | 1.02       |
# |    value_loss           | 0.256      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -10.5     |
# | time/                   |           |
# |    fps                  | 551       |
# |    iterations           | 67        |
# |    time_elapsed         | 248       |
# |    total_timesteps      | 137216    |
# | train/                  |           |
# |    approx_kl            | 0.2202617 |
# |    clip_fraction        | 0.581     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.97     |
# |    explained_variance   | 0.85      |
# |    learning_rate        | 0.0073    |
# |    loss                 | 0.0428    |
# |    n_updates            | 660       |
# |    policy_gradient_loss | 0.0097    |
# |    std                  | 1.06      |
# |    value_loss           | 0.232     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.9      |
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 68         |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.23001125 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.632      |
# |    learning_rate        | 0.00726    |
# |    loss                 | 0.00868    |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.00266   |
# |    std                  | 1.07       |
# |    value_loss           | 0.328      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.7      |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 69         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.22464618 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.95      |
# |    explained_variance   | 0.0921     |
# |    learning_rate        | 0.00721    |
# |    loss                 | -0.0207    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | 0.0262     |
# |    std                  | 1.07       |
# |    value_loss           | 0.16       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -10.6      |
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 70         |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.23936346 |
# |    clip_fraction        | 0.554      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.397      |
# |    learning_rate        | 0.00717    |
# |    loss                 | 0.0203     |
# |    n_updates            | 690        |
# |    policy_gradient_loss | 0.0155     |
# |    std                  | 1.05       |
# |    value_loss           | 0.31       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -11.5     |
# | time/                   |           |
# |    fps                  | 550       |
# |    iterations           | 71        |
# |    time_elapsed         | 263       |
# |    total_timesteps      | 145408    |
# | train/                  |           |
# |    approx_kl            | 0.3464523 |
# |    clip_fraction        | 0.615     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.92     |
# |    explained_variance   | 0.596     |
# |    learning_rate        | 0.00713   |
# |    loss                 | 0.0521    |
# ...
# |    iterations           | 228        |
# |    time_elapsed         | 853        |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.69024205 |
# |    clip_fraction        | 0.666      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.55       |
# |    explained_variance   | 0.695      |
# |    learning_rate        | 0.000702   |
# |    loss                 | -0.00368   |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | -0.0249    |
# |    std                  | 0.111      |
# |    value_loss           | 0.721      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.6      |
# | time/                   |            |
# |    fps                  | 546        |
# |    iterations           | 229        |
# |    time_elapsed         | 857        |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.46393952 |
# |    clip_fraction        | 0.633      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.6        |
# |    explained_variance   | 0.412      |
# |    learning_rate        | 0.000661   |
# |    loss                 | 2.15       |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | -0.023     |
# |    std                  | 0.11       |
# |    value_loss           | 2.24       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.5      |
# | time/                   |            |
# |    fps                  | 546        |
# |    iterations           | 230        |
# |    time_elapsed         | 861        |
# |    total_timesteps      | 471040     |
# | train/                  |            |
# |    approx_kl            | 0.53234017 |
# |    clip_fraction        | 0.621      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.63       |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.00062    |
# |    loss                 | 0.424      |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | -0.0146    |
# |    std                  | 0.106      |
# |    value_loss           | 6.91       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -15.8     |
# | time/                   |           |
# |    fps                  | 547       |
# |    iterations           | 231       |
# |    time_elapsed         | 864       |
# |    total_timesteps      | 473088    |
# | train/                  |           |
# |    approx_kl            | 6.1509056 |
# |    clip_fraction        | 0.674     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.68      |
# |    explained_variance   | 0.781     |
# |    learning_rate        | 0.000579  |
# |    loss                 | 0.216     |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | 0.00902   |
# |    std                  | 0.104     |
# |    value_loss           | 1.73      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -15.5     |
# | time/                   |           |
# |    fps                  | 547       |
# |    iterations           | 232       |
# |    time_elapsed         | 868       |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 0.2879913 |
# |    clip_fraction        | 0.557     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.74      |
# |    explained_variance   | 0.816     |
# |    learning_rate        | 0.000538  |
# |    loss                 | 0.233     |
# |    n_updates            | 2310      |
# |    policy_gradient_loss | -0.0296   |
# |    std                  | 0.1       |
# |    value_loss           | 2.01      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.4      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 233        |
# |    time_elapsed         | 872        |
# |    total_timesteps      | 477184     |
# | train/                  |            |
# |    approx_kl            | 0.28905421 |
# |    clip_fraction        | 0.536      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.78       |
# |    explained_variance   | 0.674      |
# |    learning_rate        | 0.000497   |
# |    loss                 | 0.138      |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | -0.0258    |
# |    std                  | 0.0989     |
# |    value_loss           | 1.21       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.17e+03  |
# |    ep_rew_mean          | -15.8     |
# | time/                   |           |
# |    fps                  | 547       |
# |    iterations           | 234       |
# |    time_elapsed         | 875       |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 2.0115616 |
# |    clip_fraction        | 0.57      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.84      |
# |    explained_variance   | 0.859     |
# |    learning_rate        | 0.000456  |
# |    loss                 | 0.181     |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | -0.0432   |
# |    std                  | 0.0951    |
# |    value_loss           | 0.909     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.17e+03  |
# |    ep_rew_mean          | -16.1     |
# | time/                   |           |
# |    fps                  | 547       |
# |    iterations           | 235       |
# |    time_elapsed         | 879       |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 0.2628175 |
# |    clip_fraction        | 0.512     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.9       |
# |    explained_variance   | 0.636     |
# |    learning_rate        | 0.000415  |
# |    loss                 | 0.203     |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | -0.0459   |
# |    std                  | 0.0937    |
# |    value_loss           | 1.01      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | -16.5      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 236        |
# |    time_elapsed         | 883        |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.18689227 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.000374   |
# |    loss                 | 0.815      |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.037     |
# |    std                  | 0.09       |
# |    value_loss           | 4.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.7      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 237        |
# |    time_elapsed         | 887        |
# |    total_timesteps      | 485376     |
# | train/                  |            |
# |    approx_kl            | 0.22337696 |
# |    clip_fraction        | 0.532      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.01       |
# |    explained_variance   | 0.707      |
# |    learning_rate        | 0.000333   |
# |    loss                 | 0.425      |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | -0.0491    |
# |    std                  | 0.089      |
# |    value_loss           | 1.43       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -15.3     |
# | time/                   |           |
# |    fps                  | 547       |
# |    iterations           | 238       |
# |    time_elapsed         | 891       |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 0.1800113 |
# |    clip_fraction        | 0.472     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.04      |
# |    explained_variance   | 0.531     |
# |    learning_rate        | 0.000292  |
# |    loss                 | 0.819     |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | -0.0314   |
# |    std                  | 0.0879    |
# |    value_loss           | 6.25      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.4      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 239        |
# |    time_elapsed         | 894        |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.77670723 |
# |    clip_fraction        | 0.49       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.06       |
# |    explained_variance   | 0.818      |
# |    learning_rate        | 0.000252   |
# |    loss                 | 0.252      |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0183    |
# |    std                  | 0.0873     |
# |    value_loss           | 0.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -14.9      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 240        |
# |    time_elapsed         | 898        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.19428104 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.07       |
# |    explained_variance   | 0.788      |
# |    learning_rate        | 0.000211   |
# |    loss                 | 0.162      |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.0459    |
# |    std                  | 0.0862     |
# |    value_loss           | 0.843      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -15.5      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 241        |
# |    time_elapsed         | 902        |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.06429436 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.1        |
# |    explained_variance   | 0.628      |
# |    learning_rate        | 0.00017    |
# |    loss                 | 0.546      |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.085      |
# |    value_loss           | 1.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -15.7       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 242         |
# |    time_elapsed         | 906         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.048053335 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.13        |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.000129    |
# |    loss                 | 2.31        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.0411     |
# |    std                  | 0.0844      |
# |    value_loss           | 5.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 243         |
# |    time_elapsed         | 910         |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.046102718 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.14        |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 8.77e-05    |
# |    loss                 | 2.6         |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.046      |
# |    std                  | 0.0837      |
# |    value_loss           | 4.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -16.6       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 244         |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.021862747 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.16        |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 4.67e-05    |
# |    loss                 | 0.868       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.0415     |
# |    std                  | 0.0835      |
# |    value_loss           | 1.64        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.17e+03     |
# |    ep_rew_mean          | -16.7        |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 245          |
# |    time_elapsed         | 917          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0044962703 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 2.16         |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 5.76e-06     |
# |    loss                 | 0.702        |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.0151      |
# |    std                  | 0.0834       |
# |    value_loss           | 1.63         |
# ------------------------------------------

# %%
## EXPERIMENT 2

def linear_schedule_up(final_value: float):
    """
    Linear learning rate schedule.The learning rate value will increase

    :param final_value: Final learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return (1-progress_remaining) * final_value

    return func

## EXPERIMENT 2

def linear_schedule_up(final_value: float):
    """
    Linear learning rate schedule.The learning rate value will increase

    :param final_value: Final learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return (1-progress_remaining) * final_value

    return func

for i in range(EX_LOOP):
  if i > 0:
    del env
    del model_up
  # Initial learning rate of 0.001
  env = gym.make('VSS1vs1-v0')
  csv_name = f"log{i}_PPO_up"
  env = stable_baselines3.common.monitor.Monitor(env,csv_name)
  env.reset()
  model_up = PPO("MlpPolicy", env, learning_rate=linear_schedule_up(0.01), verbose=1)
  model_up.learn(total_timesteps=500_000)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# |    loss                 | 0.0894      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.967       |
# |    value_loss           | 0.706       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -16.4       |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011814199 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.000737    |
# |    loss                 | 0.164       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.957       |
# |    value_loss           | 0.451       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | -15.6        |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 20           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0074033616 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | -0.0659      |
# |    learning_rate        | 0.000778     |
# |    loss                 | 0.379        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00662     |
# |    std                  | 0.957        |
# |    value_loss           | 1.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -16.2       |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 21          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011933478 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.000819    |
# |    loss                 | 0.187       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.967       |
# |    value_loss           | 0.445       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | -16.4        |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 22           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0113901235 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.00086      |
# |    loss                 | 0.0913       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.975        |
# |    value_loss           | 0.274        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 23          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008028602 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.000901    |
# |    loss                 | 0.404       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0042     |
# |    std                  | 0.951       |
# |    value_loss           | 0.665       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 24          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010687798 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.000942    |
# |    loss                 | 0.0608      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.941       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 25          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011624087 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.000983    |
# |    loss                 | 0.045       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00872    |
# |    std                  | 0.926       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | -14.8      |
# | time/                   |            |
# |    fps                  | 569        |
# |    iterations           | 26         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00879851 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.00102    |
# |    loss                 | 0.0594     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.935      |
# |    value_loss           | 0.136      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -14.3       |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 27          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011770522 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.00106     |
# |    loss                 | 0.0302      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00891    |
# |    std                  | 0.919       |
# |    value_loss           | 0.166       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -15.4       |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 28          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012567373 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.00111     |
# |    loss                 | 0.122       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00639    |
# |    std                  | 0.901       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | -15.3        |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 29           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0114822555 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 0.00115      |
# |    loss                 | 0.193        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00846     |
# |    std                  | 0.915        |
# |    value_loss           | 1.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 30          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009897374 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.00119     |
# |    loss                 | 0.115       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.907       |
# |    value_loss           | 0.435       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 31          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011978424 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.00123     |
# |    loss                 | 0.0953      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.887       |
# |    value_loss           | 0.527       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -13.9       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 32          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010828543 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.00127     |
# |    loss                 | 0.0891      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00804    |
# |    std                  | 0.903       |
# |    value_loss           | 0.209       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.9       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 33          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014376232 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.00131     |
# |    loss                 | 0.0851      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00953    |
# |    std                  | 0.907       |
# |    value_loss           | 0.296       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.6       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 34          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015311618 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.00135     |
# |    loss                 | 0.221       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.891       |
# |    value_loss           | 0.734       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 35          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012110464 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.00139     |
# |    loss                 | 0.18        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00881    |
# |    std                  | 0.896       |
# |    value_loss           | 0.485       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 36          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017055005 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.00143     |
# |    loss                 | 0.105       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.881       |
# |    value_loss           | 0.538       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | -12.4        |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 37           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0140548665 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.00147      |
# |    loss                 | 0.198        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.878        |
# |    value_loss           | 0.484        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 38          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.019775871 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.00152     |
# |    loss                 | 0.153       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.856       |
# |    value_loss           | 0.433       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -11.2      |
# | time/                   |            |
# |    fps                  | 567        |
# |    iterations           | 39         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01384742 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.518      |
# |    learning_rate        | 0.00156    |
# |    loss                 | 0.0338     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0116    |
# |    std                  | 0.857      |
# |    value_loss           | 0.192      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 40          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010087343 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0016      |
# |    loss                 | 0.345       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.86        |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 41          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012212289 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.00164     |
# |    loss                 | 0.104       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00937    |
# |    std                  | 0.854       |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 42          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024925109 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.00168     |
# |    loss                 | 0.102       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.828       |
# |    value_loss           | 0.422       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -10.2       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 43          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.021547202 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.00172     |
# |    loss                 | 0.0346      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.825       |
# |    value_loss           | 0.282       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -10.1      |
# | time/                   |            |
# |    fps                  | 566        |
# |    iterations           | 44         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01570465 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.00176    |
# |    loss                 | 0.0132     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00985   |
# |    std                  | 0.816      |
# |    value_loss           | 0.162      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -9.51       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 45          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018634718 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0018      |
# |    loss                 | 0.019       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.803       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | -9.1         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 46           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0153830955 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 0.00184      |
# |    loss                 | 0.0483       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0096      |
# |    std                  | 0.774        |
# |    value_loss           | 0.56         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -9.04       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 47          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.025666067 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.00188     |
# |    loss                 | 0.138       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.749       |
# |    value_loss           | 0.619       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.39       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 48          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018479804 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.00193     |
# |    loss                 | 0.319       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00726    |
# |    std                  | 0.749       |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -9.05      |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 49         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02531347 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 0.00197    |
# |    loss                 | 0.075      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.746      |
# |    value_loss           | 0.627      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -9.45       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 50          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.015780287 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.00201     |
# |    loss                 | 0.261       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.75        |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -9.11       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 51          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.026172735 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.00205     |
# |    loss                 | 0.243       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.735       |
# |    value_loss           | 0.999       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -9.15       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 52          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.030453943 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.00209     |
# |    loss                 | 0.102       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.717       |
# |    value_loss           | 0.895       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -8.49      |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 53         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.02736869 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.75       |
# |    learning_rate        | 0.00213    |
# |    loss                 | 0.0506     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0122    |
# |    std                  | 0.716      |
# |    value_loss           | 0.346      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.08       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 54          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.020887248 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.00217     |
# |    loss                 | 0.176       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00649    |
# |    std                  | 0.699       |
# |    value_loss           | 0.932       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -7.99       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 55          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.026733005 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.00221     |
# |    loss                 | 0.0711      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00975    |
# |    std                  | 0.687       |
# |    value_loss           | 0.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.07       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 56          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.029368566 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.00225     |
# |    loss                 | 0.141       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00815    |
# |    std                  | 0.664       |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -8.03      |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 57         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.04065854 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.00229    |
# |    loss                 | 0.00836    |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00735   |
# |    std                  | 0.655      |
# |    value_loss           | 0.387      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.38       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 58          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.028300032 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.00233     |
# |    loss                 | 0.0222      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.649       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.35       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 59          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.028515242 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.00238     |
# |    loss                 | 0.00606     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.633       |
# |    value_loss           | 0.843       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -7.91       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 60          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.023002664 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.00242     |
# |    loss                 | 0.0416      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.627       |
# |    value_loss           | 0.176       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -8.03       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 61          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.028281987 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.00246     |
# |    loss                 | 0.0132      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00921    |
# |    std                  | 0.621       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -7.89       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 62          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.026630472 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0025      |
# |    loss                 | 0.0326      |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.000136    |
# |    std                  | 0.626       |
# |    value_loss           | 0.285       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -7.44       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 63          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.042543948 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.00254     |
# |    loss                 | 0.0875      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.619       |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -7.64       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 64          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.034640886 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.00258     |
# |    loss                 | 0.0597      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.0057     |
# |    std                  | 0.609       |
# |    value_loss           | 0.532       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -7.09      |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 65         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 133120     |
# | train/                  |            |
# |    approx_kl            | 0.02999025 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.88      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 0.00262    |
# |    loss                 | 0.0526     |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 0.615      |
# |    value_loss           | 0.581      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -7          |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 66          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.039671898 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.00266     |
# |    loss                 | 0.105       |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00897    |
# |    std                  | 0.612       |
# |    value_loss           | 0.562       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -6.14      |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 67         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.03548367 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0027     |
# |    loss                 | 0.0652     |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.00802   |
# |    std                  | 0.596      |
# |    value_loss           | 0.233      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.15e+03  |
# |    ep_rew_mean          | -6.05     |
# | time/                   |           |
# |    fps                  | 564       |
# |    iterations           | 68        |
# |    time_elapsed         | 246       |
# |    total_timesteps      | 139264    |
# | train/                  |           |
# |    approx_kl            | 0.0351296 |
# |    clip_fraction        | 0.277     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.79     |
# |    explained_variance   | 0.628     |
# |    learning_rate        | 0.00274   |
# |    loss                 | 0.0101    |
# |    n_updates            | 670       |
# |    policy_gradient_loss | -0.00644  |
# |    std                  | 0.587     |
# |    value_loss           | 0.132     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -6.67      |
# | time/                   |            |
# |    fps                  | 563        |
# |    iterations           | 69         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.03942998 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.00279    |
# |    loss                 | 0.0703     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0107    |
# |    std                  | 0.578      |
# |    value_loss           | 0.3        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -6.69       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 70          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.035104603 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.00283     |
# ...
# |    value_loss           | 0.183      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | -19.9      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 228        |
# |    time_elapsed         | 841        |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.47097602 |
# |    clip_fraction        | 0.683      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0093     |
# |    loss                 | 0.0231     |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | 0.0237     |
# |    std                  | 0.866      |
# |    value_loss           | 0.143      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -20.4      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 229        |
# |    time_elapsed         | 845        |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.52667564 |
# |    clip_fraction        | 0.653      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.58      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.00934    |
# |    loss                 | 0.0406     |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.027      |
# |    std                  | 0.869      |
# |    value_loss           | 0.193      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -20.3      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 230        |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 471040     |
# | train/                  |            |
# |    approx_kl            | 0.37157595 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.519      |
# |    learning_rate        | 0.00938    |
# |    loss                 | 0.0175     |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | -0.00543   |
# |    std                  | 0.862      |
# |    value_loss           | 0.497      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -20.6      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 231        |
# |    time_elapsed         | 853        |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.61530185 |
# |    clip_fraction        | 0.693      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.64      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.00942    |
# |    loss                 | 0.0734     |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | 0.0411     |
# |    std                  | 0.889      |
# |    value_loss           | 0.134      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -20.6     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 232       |
# |    time_elapsed         | 856       |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 1.4787275 |
# |    clip_fraction        | 0.719     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.62     |
# |    explained_variance   | 0.716     |
# |    learning_rate        | 0.00946   |
# |    loss                 | 0.157     |
# |    n_updates            | 2310      |
# |    policy_gradient_loss | 0.0361    |
# |    std                  | 0.899     |
# |    value_loss           | 0.259     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -21       |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 233       |
# |    time_elapsed         | 860       |
# |    total_timesteps      | 477184    |
# | train/                  |           |
# |    approx_kl            | 2.7722228 |
# |    clip_fraction        | 0.747     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.67     |
# |    explained_variance   | 0.611     |
# |    learning_rate        | 0.0095    |
# |    loss                 | 0.0207    |
# |    n_updates            | 2320      |
# |    policy_gradient_loss | 0.0283    |
# |    std                  | 0.912     |
# |    value_loss           | 0.115     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -21       |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 234       |
# |    time_elapsed         | 863       |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 0.6604532 |
# |    clip_fraction        | 0.699     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.7      |
# |    explained_variance   | 0.742     |
# |    learning_rate        | 0.00954   |
# |    loss                 | 0.07      |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | 0.0178    |
# |    std                  | 0.922     |
# |    value_loss           | 0.285     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -20.9     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 235       |
# |    time_elapsed         | 867       |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 1.8430309 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.72     |
# |    explained_variance   | 0.833     |
# |    learning_rate        | 0.00958   |
# |    loss                 | 0.0817    |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | 0.0577    |
# |    std                  | 0.917     |
# |    value_loss           | 0.098     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -20.9     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 236       |
# |    time_elapsed         | 871       |
# |    total_timesteps      | 483328    |
# | train/                  |           |
# |    approx_kl            | 1.0686405 |
# |    clip_fraction        | 0.614     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.73     |
# |    explained_variance   | 0.93      |
# |    learning_rate        | 0.00963   |
# |    loss                 | 0.0293    |
# |    n_updates            | 2350      |
# |    policy_gradient_loss | 0.0794    |
# |    std                  | 0.914     |
# |    value_loss           | 0.0568    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -21       |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 237       |
# |    time_elapsed         | 875       |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 1.6260778 |
# |    clip_fraction        | 0.724     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.7      |
# |    explained_variance   | 0.361     |
# |    learning_rate        | 0.00967   |
# |    loss                 | 0.124     |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | 0.0438    |
# |    std                  | 0.905     |
# |    value_loss           | 1.39      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -20.7     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 238       |
# |    time_elapsed         | 878       |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 1.7578624 |
# |    clip_fraction        | 0.738     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.71     |
# |    explained_variance   | 0.472     |
# |    learning_rate        | 0.00971   |
# |    loss                 | 0.16      |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 0.0396    |
# |    std                  | 0.938     |
# |    value_loss           | 0.641     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -20.4     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 239       |
# |    time_elapsed         | 882       |
# |    total_timesteps      | 489472    |
# | train/                  |           |
# |    approx_kl            | 3.3434477 |
# |    clip_fraction        | 0.716     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.7      |
# |    explained_variance   | 0.722     |
# |    learning_rate        | 0.00975   |
# |    loss                 | -0.0153   |
# |    n_updates            | 2380      |
# |    policy_gradient_loss | 0.0429    |
# |    std                  | 0.876     |
# |    value_loss           | 0.434     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.16e+03 |
# |    ep_rew_mean          | -20.5    |
# | time/                   |          |
# |    fps                  | 554      |
# |    iterations           | 240      |
# |    time_elapsed         | 886      |
# |    total_timesteps      | 491520   |
# | train/                  |          |
# |    approx_kl            | 1.241316 |
# |    clip_fraction        | 0.757    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.62    |
# |    explained_variance   | 0.793    |
# |    learning_rate        | 0.00979  |
# |    loss                 | 0.105    |
# |    n_updates            | 2390     |
# |    policy_gradient_loss | 0.0462   |
# |    std                  | 0.869    |
# |    value_loss           | 0.397    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.16e+03 |
# |    ep_rew_mean          | -20.9    |
# | time/                   |          |
# |    fps                  | 554      |
# |    iterations           | 241      |
# |    time_elapsed         | 889      |
# |    total_timesteps      | 493568   |
# | train/                  |          |
# |    approx_kl            | 2.649323 |
# |    clip_fraction        | 0.757    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.57    |
# |    explained_variance   | 0.311    |
# |    learning_rate        | 0.00983  |
# |    loss                 | 0.0668   |
# |    n_updates            | 2400     |
# |    policy_gradient_loss | 0.0525   |
# |    std                  | 0.829    |
# |    value_loss           | 0.398    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.16e+03 |
# |    ep_rew_mean          | -21.1    |
# | time/                   |          |
# |    fps                  | 554      |
# |    iterations           | 242      |
# |    time_elapsed         | 893      |
# |    total_timesteps      | 495616   |
# | train/                  |          |
# |    approx_kl            | 2.104051 |
# |    clip_fraction        | 0.794    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.58    |
# |    explained_variance   | 0.736    |
# |    learning_rate        | 0.00987  |
# |    loss                 | 0.0656   |
# |    n_updates            | 2410     |
# |    policy_gradient_loss | 0.0585   |
# |    std                  | 0.857    |
# |    value_loss           | 0.185    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.16e+03   |
# |    ep_rew_mean          | -21.4      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 243        |
# |    time_elapsed         | 896        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.76587546 |
# |    clip_fraction        | 0.764      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.00991    |
# |    loss                 | 0.0694     |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | 0.054      |
# |    std                  | 0.924      |
# |    value_loss           | 0.141      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.16e+03  |
# |    ep_rew_mean          | -21.3     |
# | time/                   |           |
# |    fps                  | 554       |
# |    iterations           | 244       |
# |    time_elapsed         | 900       |
# |    total_timesteps      | 499712    |
# | train/                  |           |
# |    approx_kl            | 0.8989401 |
# |    clip_fraction        | 0.724     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.78     |
# |    explained_variance   | 0.653     |
# |    learning_rate        | 0.00995   |
# |    loss                 | 0.126     |
# |    n_updates            | 2430      |
# |    policy_gradient_loss | 0.0673    |
# |    std                  | 1         |
# |    value_loss           | 0.137     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | -20.8      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 245        |
# |    time_elapsed         | 904        |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.96269906 |
# |    clip_fraction        | 0.717      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.187      |
# |    learning_rate        | 0.00999    |
# |    loss                 | 0.226      |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | 0.0233     |
# |    std                  | 1.02       |
# |    value_loss           | 1.06       |
# ----------------------------------------

# %% [markdown]
# # Mostrar gráficas archivos CSV
# Por último, se crean las gráficas que representan la evolución media de las recompensas a lo largo de los valores de *learning rate* a partir de los archivos CSV que se han guardado gracias al *wrapper* Monitor que se ha instanciado.
#
# Habra dos gráficas, una representará la evolución de las recompensas para el caso en el que la tasa de aprendizaje es ascendente y otra para cuando el valor de dicha tasa va descendiendo. Esta distinción es debida a que en los primeros momentos en los que el algoritmo se va ejecutando este realmente no mejora su comportamiento de forma muy notable porque todavía está aprendiendo. Esto hace que el verdadero impacto del valor de la tasa de aprendizaje se aprecie más en las iteraciones más cercanas al final del entrenamiento y por ello se ha querido que todos los valores de la tasa de aprendizaje que se querían testear se alojaran en la parte final del entrenamiento.
#
# Además, se ha hecho una normalización de los valores de recompensa dividiendo todos los valores de cada uno de los archivos CSV entre el valor máximo de dicho archivo para mitigar el efecto que tiene el hecho de empezar con una recompensa muy alta o muy baja(puesto que es algo aleatorio).

# %%
import os
from google.colab import drive
import csv
import numpy as np
import matplotlib.pyplot as plt


def norm_vector(vec):
  positive_vec = vec + abs(np.min(vec))
  norm_vec = positive_vec * 100 / np.max(positive_vec)
  return norm_vec


def calculate_media_std(vec1, vec2, vec3):
  final_array = []
  vec1 = norm_vector(vec1)
  vec2 = norm_vector(vec2)
  vec3 = norm_vector(vec3)

  for v1,v2,v3 in zip(vec1,vec2,vec3):
    final_array.append((v1+v2+v3)/3)
    final_array.append(np.std([v1,v2,v3]))

  return np.array(final_array).reshape(vec1.size, 2)


# Path to the folder containing csv files
FOLDER_PATH = "./drive/MyDrive/Colab Notebooks/TFG/Entrenamiento en rSoccer/Entorno simulado/Fase 1 Ajuste de hiperparámetros"

# Path to csv files
CSV_DOWN_0 = os.path.join(FOLDER_PATH, "log0_PPO_down.monitor.csv")
CSV_DOWN_1 = os.path.join(FOLDER_PATH, "log1_PPO_down.monitor.csv")
CSV_DOWN_2 = os.path.join(FOLDER_PATH, "log2_PPO_down.monitor.csv")
CSV_UP_0 = os.path.join(FOLDER_PATH, "log0_PPO_up.monitor.csv")
CSV_UP_1 = os.path.join(FOLDER_PATH, "log1_PPO_up.monitor.csv")
CSV_UP_2 = os.path.join(FOLDER_PATH, "log2_PPO_up.monitor.csv")

# Create a local directory to access my files stored in google drive
drive.mount("./drive")

# Create empty lists to fill them with rewards values of csv files and
# convert them to numpy arrays
reward_down_0 = []
reward_down_1 = []
reward_down_2 = []
with open(CSV_DOWN_0,"r") as csv0, open(CSV_DOWN_1,"r") as csv1, open(CSV_DOWN_2,"r") as csv2:
  csv0_read = csv.reader(csv0)
  csv1_read = csv.reader(csv1)
  csv2_read = csv.reader(csv2)
  next(csv0_read)
  next(csv1_read)
  next(csv2_read)
  for rows0, rows1, rows2 in zip(csv0_read, csv1_read, csv2_read):
    reward_down_0.append(float(rows0[0]))
    reward_down_1.append(float(rows1[0]))
    reward_down_2.append(float(rows2[0]))

reward_up_0 = []
reward_up_1 = []
reward_up_2 = []
with open(CSV_UP_0,"r") as csv0, open(CSV_UP_1,"r") as csv1, open(CSV_UP_2,"r") as csv2:
  csv0_read = csv.reader(csv0)
  csv1_read = csv.reader(csv1)
  csv2_read = csv.reader(csv2)
  next(csv0_read)
  next(csv1_read)
  next(csv2_read)
  for rows0, rows1, rows2 in zip(csv0_read, csv1_read, csv2_read):
    reward_up_0.append(float(rows0[0]))
    reward_up_1.append(float(rows1[0]))
    reward_up_2.append(float(rows2[0]))

reward_down_0 = np.array(reward_down_0)
reward_down_1 = np.array(reward_down_1)
reward_down_2 = np.array(reward_down_2)
reward_up_0 = np.array(reward_up_0)
reward_up_1 = np.array(reward_up_1)
reward_up_2 = np.array(reward_up_2)

# Create two arrays that represent the average values of 0, 1 and 2 arrays
norm_reward_down = calculate_media_std(reward_down_0, reward_down_1, reward_down_2)
norm_reward_up = calculate_media_std(reward_up_0, reward_up_1, reward_up_2)

# Create two arrays that represent the learning rate values
lr_down = np.linspace(0.01, 1e-5, num=424)
lr_up = np.linspace(1e-5, 0.01, num=424)

# Plot graphs
figure, axis = plt.subplots(1,2)

axis[0].set_title("Learning Rate Schedule down")
axis[0].plot(lr_down, norm_reward_down[:,0])
axis[0].fill_between(
    lr_down,
    norm_reward_down[:,0]-norm_reward_down[:,1],
    norm_reward_down[:,0]+norm_reward_down[:,1],
    color="green"
)

axis[1].set_title("Learning Rate Schedule up")
axis[1].plot(lr_up, norm_reward_up[:,0])
axis[1].fill_between(
    lr_up,
    norm_reward_up[:,0]-norm_reward_up[:,1],
    norm_reward_up[:,0]+norm_reward_up[:,1],
    color="green"
)

plt.show()
# Out:
# Drive already mounted at ./drive; to attempt to forcibly remount, call drive.mount("./drive", force_remount=True).

# %% [markdown]
# Para estas dos gráficas cada una tiene una zona de mayor interés que es la que se va a analizar:
#
# *   Learning Rate Schedule down: En este caso la zona de interés es la que va desde el principio hasta la mitad porque son los últimos valores del *learning rate*
# *   Learning Rate Schedule up: En este caso la zona de interés es la que va desde la mitad hasta el final porque son los últimos valores del *learning rate*
#
# En este caso he seleccionado **un valor óptimo de 0.003**.
