# %% [markdown]
# # Búsquea Learning Rate para DDPG
# En este cuaderno se va a realizar la experimentación necesaria para obtener el valor óptimo del hiperparámetro *learning rate* para el algoritmo DDPG(Deep Deterministic Policy Gradient).
#
# Esta búsqueda del valor óptimo se va a hacer a través de una técnica conocida como *learning rate schedule*, la cual va variando el valor de la tasa de aprendizaje a lo largo del entrenamiento para observar las recompensas que se van obteniendo para cada valor.

# %% [markdown]
# ## Instalar las librerías del entorno
# En primer lugar se hace una descarga e instalación de las librerías que se van a usar para modelar el entorno en el que se va a entrenar al agente.
#
# La primera de las librerías corresponde a un repositorio propio que se ha originado a través de un fork a otro repostorio en el que se había creado un *framework* orientado principalmente al desarrollo de entornos similares a los que se presentan en la Robocup, el cual es uno de los campeonato de fútbol robótico más conocidos a nivel mundial. Lo bueno de dicho repositorio es que los entornos que ya tiene implementados son de robots móviles y en especial los entornos VSS están formados por robots con unas carácterísticas hardware ciertamente similares a los turtlebots.
#
# La segunda librería es *gymnasium* y es un estandar dentro de la programación de entornos orientados al aprendizaje por refuerzo.

# %%
# !pip install gymnasium
# !pip install git+https://github.com/pablocarpon/rSoccer.git
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Collecting git+https://github.com/pablocarpon/rSoccer.git
#   Cloning https://github.com/pablocarpon/rSoccer.git to /tmp/pip-req-build-czv0dlwk
#   Running command git clone --filter=blob:none --quiet https://github.com/pablocarpon/rSoccer.git /tmp/pip-req-build-czv0dlwk
#   Resolved https://github.com/pablocarpon/rSoccer.git to commit bf8b88bb228835b67aba3f3b967624a12aba226a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (0.29.1)
# Requirement already satisfied: rc-robosim>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (1.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (2.5.2)
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.10/dist-packages (from rsoccer-gym==0.1.dev517+gbf8b88b) (3.20.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium->rsoccer-gym==0.1.dev517+gbf8b88b) (0.0.4)

# %% [markdown]
# ## Instalar las librerías del agente
# Tras instalar las librerías de Python que me van a ayudar a progamar el entorno, hago lo mismo con las que contienen algoritmos para regir el comportamiento del agente y optimizar su entrenamiento.
#
# En este caso estoy usando *stable_baselines3* que recoge varios algoritmos de aprendizaje por refuerzo escritos sobre la librería *pytorch*.
#
# La tercera línea de la celda inferior sirve para instalar también librerías como *tqdm* y *rich*, las cuales sirven para poder usar un *callback* que tiene *stable-baselines3* implementado con el fin de monitorizar el tiempo transcurrido durante el entrenamiento y el tiempo estimado que queda para finalizar el entrenamiento. Dicho *callback* recibe el nombre de *ProgressBarCallback*.

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Using cached stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3) (12.4.127)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, stable_baselines3
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 stable_baselines3-2.3.2

# %% [markdown]
# ## Importar todas las librerías necesarias
# Tras la instalción se importan al cuaderno todos los módulos que voy a necesitar para el entrenamiento del modelo.

# %%
import rsoccer_gym
import gymnasium as gym

import stable_baselines3
from stable_baselines3 import DDPG

# %% [markdown]
# # Entrenamiento del modelo
# En esta sección se va a proceder a entrenar el modelo con un learning rate asociado a una función que lo irá calculando en cada momento.
#
# Para esta experimentación se van a definir dos funciones de búsqueda del learning rate óptimo. Ambas funciones aceptan como parámetro el valor inicial de la tasa de aprendizaje, pero una de ellas irá aumentando el valor hasta 1 conforme pasa el tiempo y la otra lo irá reduciendo hasta 0.
#
# Con esto se pretende ver si los valores óptimos son capaces de converger en un punto o área.

# %%
# Number of times each experiment has to repeat to have a more reliable
# hyperparameter tuning
EX_LOOP = 1

# %%
## EXPERIMENT 1

def linear_schedule_down(initial_value: float):
    """
    Linear learning rate schedule. The learning rate value will decrease

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

for i in range(EX_LOOP):
  if i > 0:
    del env
    del model_down
  # Initial learning rate of 0.001
  env = gym.make('VSS1vs1-v0')
  csv_name = f"log{i}_DDPG_down"
  env = stable_baselines3.common.monitor.Monitor(env,csv_name)
  env.reset()
  model_down = DDPG("MlpPolicy", env, learning_rate=linear_schedule_down(0.01), verbose=1)
  model_down.learn(total_timesteps=500_000)
# Out:
# Environment initialized
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -18.6    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 143      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 4.01     |
# |    critic_loss     | 0.0263   |
# |    learning_rate   | 0.0099   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 141      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | 3.67     |
# |    critic_loss     | 0.0281   |
# |    learning_rate   | 0.00981  |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 139      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | 2.61     |
# |    critic_loss     | 0.0208   |
# |    learning_rate   | 0.00971  |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -29.7    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 139      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 18398    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.9      |
# |    learning_rate   | 0.00963  |
# |    n_updates       | 18297    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 139      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 22491    |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 0.0387   |
# |    learning_rate   | 0.00955  |
# |    n_updates       | 22390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -26.7    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 139      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 27291    |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.0431   |
# |    learning_rate   | 0.00945  |
# |    n_updates       | 27190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -27.8    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 138      |
# |    time_elapsed    | 232      |
# |    total_timesteps | 32091    |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 0.314    |
# |    learning_rate   | 0.00936  |
# |    n_updates       | 31990    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -26      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 138      |
# |    time_elapsed    | 266      |
# |    total_timesteps | 36891    |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.0458   |
# |    learning_rate   | 0.00926  |
# |    n_updates       | 36790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 138      |
# |    time_elapsed    | 301      |
# |    total_timesteps | 41691    |
# | train/             |          |
# |    actor_loss      | 1.95     |
# |    critic_loss     | 0.0258   |
# |    learning_rate   | 0.00917  |
# |    n_updates       | 41590    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -25.6    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 138      |
# |    time_elapsed    | 335      |
# |    total_timesteps | 46491    |
# | train/             |          |
# |    actor_loss      | 1.82     |
# |    critic_loss     | 0.00546  |
# |    learning_rate   | 0.00907  |
# |    n_updates       | 46390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.7    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 137      |
# |    time_elapsed    | 372      |
# |    total_timesteps | 51291    |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.0111   |
# |    learning_rate   | 0.00897  |
# |    n_updates       | 51190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -27.1    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 137      |
# |    time_elapsed    | 407      |
# |    total_timesteps | 56091    |
# | train/             |          |
# |    actor_loss      | 2.43     |
# |    critic_loss     | 0.579    |
# |    learning_rate   | 0.00888  |
# |    n_updates       | 55990    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -26.4    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 137      |
# |    time_elapsed    | 442      |
# |    total_timesteps | 60891    |
# | train/             |          |
# |    actor_loss      | 2.43     |
# |    critic_loss     | 0.086    |
# |    learning_rate   | 0.00878  |
# |    n_updates       | 60790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -26.5    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 137      |
# |    time_elapsed    | 477      |
# |    total_timesteps | 65691    |
# | train/             |          |
# |    actor_loss      | 2.32     |
# |    critic_loss     | 0.00988  |
# |    learning_rate   | 0.00869  |
# |    n_updates       | 65590    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -26.7    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 137      |
# |    time_elapsed    | 511      |
# |    total_timesteps | 70491    |
# | train/             |          |
# |    actor_loss      | 2.35     |
# |    critic_loss     | 0.0191   |
# |    learning_rate   | 0.00859  |
# |    n_updates       | 70390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 137      |
# |    time_elapsed    | 546      |
# |    total_timesteps | 75291    |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 0.0179   |
# |    learning_rate   | 0.00849  |
# |    n_updates       | 75190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.2    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 137      |
# |    time_elapsed    | 581      |
# |    total_timesteps | 80091    |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.267    |
# |    learning_rate   | 0.0084   |
# |    n_updates       | 79990    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.4    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 137      |
# |    time_elapsed    | 616      |
# |    total_timesteps | 84891    |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.0157   |
# |    learning_rate   | 0.0083   |
# |    n_updates       | 84790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 137      |
# |    time_elapsed    | 651      |
# |    total_timesteps | 89691    |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 0.0177   |
# |    learning_rate   | 0.00821  |
# |    n_updates       | 89590    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.5    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 137      |
# |    time_elapsed    | 685      |
# |    total_timesteps | 94491    |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.036    |
# |    learning_rate   | 0.00811  |
# |    n_updates       | 94390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.2    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 137      |
# |    time_elapsed    | 720      |
# |    total_timesteps | 99291    |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.0107   |
# |    learning_rate   | 0.00801  |
# |    n_updates       | 99190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.6    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 137      |
# |    time_elapsed    | 755      |
# |    total_timesteps | 104091   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.000782 |
# |    learning_rate   | 0.00792  |
# |    n_updates       | 103990   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.7    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 137      |
# |    time_elapsed    | 789      |
# |    total_timesteps | 108891   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.00782  |
# |    n_updates       | 108790   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 137      |
# |    time_elapsed    | 824      |
# |    total_timesteps | 113691   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.00469  |
# |    learning_rate   | 0.00773  |
# |    n_updates       | 113590   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.2    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 137      |
# |    time_elapsed    | 860      |
# |    total_timesteps | 118491   |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.00805  |
# |    learning_rate   | 0.00763  |
# |    n_updates       | 118390   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 137      |
# |    time_elapsed    | 895      |
# |    total_timesteps | 123291   |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.0255   |
# |    learning_rate   | 0.00753  |
# |    n_updates       | 123190   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.9    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 137      |
# |    time_elapsed    | 929      |
# |    total_timesteps | 128091   |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.0231   |
# |    learning_rate   | 0.00744  |
# |    n_updates       | 127990   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.6    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 137      |
# |    time_elapsed    | 964      |
# |    total_timesteps | 132891   |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.00282  |
# |    learning_rate   | 0.00734  |
# |    n_updates       | 132790   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 137      |
# |    time_elapsed    | 998      |
# |    total_timesteps | 137691   |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.00558  |
# |    learning_rate   | 0.00725  |
# |    n_updates       | 137590   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -25.1    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 137      |
# |    time_elapsed    | 1034     |
# |    total_timesteps | 142491   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 0.0101   |
# |    learning_rate   | 0.00715  |
# |    n_updates       | 142390   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -25      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 137      |
# |    time_elapsed    | 1068     |
# |    total_timesteps | 147291   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.016    |
# |    learning_rate   | 0.00705  |
# |    n_updates       | 147190   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 137      |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 150913   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0257   |
# |    learning_rate   | 0.00698  |
# |    n_updates       | 150812   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 137      |
# |    time_elapsed    | 1125     |
# |    total_timesteps | 155113   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.00679  |
# |    learning_rate   | 0.0069   |
# |    n_updates       | 155012   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 137      |
# |    time_elapsed    | 1160     |
# |    total_timesteps | 159913   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 0.00433  |
# |    learning_rate   | 0.0068   |
# |    n_updates       | 159812   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 137      |
# |    time_elapsed    | 1195     |
# |    total_timesteps | 164713   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.00371  |
# |    learning_rate   | 0.00671  |
# |    n_updates       | 164612   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 137      |
# |    time_elapsed    | 1229     |
# |    total_timesteps | 169513   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00863  |
# |    learning_rate   | 0.00661  |
# |    n_updates       | 169412   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.1    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 137      |
# |    time_elapsed    | 1261     |
# |    total_timesteps | 173803   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00603  |
# |    learning_rate   | 0.00652  |
# |    n_updates       | 173702   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 137      |
# |    time_elapsed    | 1295     |
# |    total_timesteps | 178603   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00293  |
# |    learning_rate   | 0.00643  |
# |    n_updates       | 178502   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 137      |
# |    time_elapsed    | 1330     |
# |    total_timesteps | 183403   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00363  |
# |    learning_rate   | 0.00633  |
# |    n_updates       | 183302   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.2    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 137      |
# |    time_elapsed    | 1357     |
# |    total_timesteps | 187119   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.00289  |
# |    learning_rate   | 0.00626  |
# |    n_updates       | 187018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 137      |
# |    time_elapsed    | 1392     |
# |    total_timesteps | 191919   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.00275  |
# |    learning_rate   | 0.00616  |
# |    n_updates       | 191818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 137      |
# |    time_elapsed    | 1427     |
# |    total_timesteps | 196719   |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00455  |
# |    learning_rate   | 0.00607  |
# |    n_updates       | 196618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 137      |
# |    time_elapsed    | 1461     |
# |    total_timesteps | 201519   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00883  |
# |    learning_rate   | 0.00597  |
# |    n_updates       | 201418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 137      |
# |    time_elapsed    | 1496     |
# |    total_timesteps | 206319   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00263  |
# |    learning_rate   | 0.00587  |
# |    n_updates       | 206218   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 137      |
# |    time_elapsed    | 1531     |
# |    total_timesteps | 211119   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.0103   |
# |    learning_rate   | 0.00578  |
# |    n_updates       | 211018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.3    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 137      |
# |    time_elapsed    | 1566     |
# |    total_timesteps | 215919   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.0142   |
# |    learning_rate   | 0.00568  |
# |    n_updates       | 215818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 137      |
# |    time_elapsed    | 1600     |
# |    total_timesteps | 220719   |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.01     |
# |    learning_rate   | 0.00559  |
# |    n_updates       | 220618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -23.9    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 137      |
# |    time_elapsed    | 1636     |
# |    total_timesteps | 225519   |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.0054   |
# |    learning_rate   | 0.00549  |
# |    n_updates       | 225418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.4    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 137      |
# |    time_elapsed    | 1671     |
# |    total_timesteps | 230319   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00816  |
# |    learning_rate   | 0.00539  |
# |    n_updates       | 230218   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 137      |
# |    time_elapsed    | 1705     |
# |    total_timesteps | 235119   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.00554  |
# |    learning_rate   | 0.0053   |
# |    n_updates       | 235018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 137      |
# |    time_elapsed    | 1740     |
# |    total_timesteps | 239919   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.0015   |
# |    learning_rate   | 0.0052   |
# |    n_updates       | 239818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.2    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 137      |
# |    time_elapsed    | 1774     |
# |    total_timesteps | 244719   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.0119   |
# |    learning_rate   | 0.00511  |
# |    n_updates       | 244618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 137      |
# |    time_elapsed    | 1809     |
# |    total_timesteps | 249519   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00392  |
# |    learning_rate   | 0.00501  |
# |    n_updates       | 249418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 137      |
# |    time_elapsed    | 1843     |
# |    total_timesteps | 254319   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.0156   |
# |    learning_rate   | 0.00491  |
# |    n_updates       | 254218   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.8    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 137      |
# |    time_elapsed    | 1878     |
# |    total_timesteps | 259119   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.00259  |
# |    learning_rate   | 0.00482  |
# |    n_updates       | 259018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 137      |
# |    time_elapsed    | 1912     |
# |    total_timesteps | 263919   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.0081   |
# |    learning_rate   | 0.00472  |
# |    n_updates       | 263818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.3    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 137      |
# |    time_elapsed    | 1947     |
# |    total_timesteps | 268719   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00821  |
# |    learning_rate   | 0.00463  |
# |    n_updates       | 268618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 138      |
# |    time_elapsed    | 1981     |
# |    total_timesteps | 273519   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00242  |
# |    learning_rate   | 0.00453  |
# |    n_updates       | 273418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.1    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 138      |
# |    time_elapsed    | 2016     |
# |    total_timesteps | 278319   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.01     |
# |    learning_rate   | 0.00443  |
# |    n_updates       | 278218   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 138      |
# |    time_elapsed    | 2051     |
# |    total_timesteps | 283119   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.00415  |
# |    learning_rate   | 0.00434  |
# |    n_updates       | 283018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.9    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 138      |
# |    time_elapsed    | 2085     |
# |    total_timesteps | 287919   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.0017   |
# |    learning_rate   | 0.00424  |
# |    n_updates       | 287818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.9    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 138      |
# |    time_elapsed    | 2120     |
# |    total_timesteps | 292719   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.00369  |
# |    learning_rate   | 0.00415  |
# |    n_updates       | 292618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 138      |
# |    time_elapsed    | 2148     |
# |    total_timesteps | 296574   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.0114   |
# |    learning_rate   | 0.00407  |
# |    n_updates       | 296473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.4    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 137      |
# |    time_elapsed    | 2184     |
# |    total_timesteps | 301374   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00299  |
# |    learning_rate   | 0.00397  |
# |    n_updates       | 301273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 137      |
# |    time_elapsed    | 2218     |
# |    total_timesteps | 306174   |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.0172   |
# |    learning_rate   | 0.00388  |
# |    n_updates       | 306073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 137      |
# |    time_elapsed    | 2254     |
# |    total_timesteps | 310974   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00074  |
# |    learning_rate   | 0.00378  |
# |    n_updates       | 310873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.4    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 137      |
# |    time_elapsed    | 2290     |
# |    total_timesteps | 315774   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.0045   |
# |    learning_rate   | 0.00368  |
# |    n_updates       | 315673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 137      |
# |    time_elapsed    | 2326     |
# |    total_timesteps | 320574   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00713  |
# |    learning_rate   | 0.00359  |
# |    n_updates       | 320473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 137      |
# |    time_elapsed    | 2361     |
# |    total_timesteps | 325374   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.0114   |
# |    learning_rate   | 0.00349  |
# |    n_updates       | 325273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 137      |
# |    time_elapsed    | 2396     |
# |    total_timesteps | 330174   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00735  |
# |    learning_rate   | 0.0034   |
# |    n_updates       | 330073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.2    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 137      |
# |    time_elapsed    | 2431     |
# |    total_timesteps | 334974   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00364  |
# |    learning_rate   | 0.0033   |
# |    n_updates       | 334873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.4    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 137      |
# |    time_elapsed    | 2468     |
# |    total_timesteps | 339774   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.0114   |
# |    learning_rate   | 0.0032   |
# |    n_updates       | 339673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.2    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 137      |
# |    time_elapsed    | 2504     |
# |    total_timesteps | 344574   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00706  |
# |    learning_rate   | 0.00311  |
# |    n_updates       | 344473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 137      |
# |    time_elapsed    | 2540     |
# |    total_timesteps | 349374   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00413  |
# |    learning_rate   | 0.00301  |
# |    n_updates       | 349273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 137      |
# |    time_elapsed    | 2575     |
# |    total_timesteps | 354174   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00493  |
# |    learning_rate   | 0.00292  |
# |    n_updates       | 354073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 137      |
# |    time_elapsed    | 2610     |
# |    total_timesteps | 358974   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00439  |
# |    learning_rate   | 0.00282  |
# |    n_updates       | 358873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 137      |
# |    time_elapsed    | 2644     |
# |    total_timesteps | 363774   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00736  |
# |    learning_rate   | 0.00272  |
# |    n_updates       | 363673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.7    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 137      |
# |    time_elapsed    | 2679     |
# |    total_timesteps | 368574   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.014    |
# |    learning_rate   | 0.00263  |
# |    n_updates       | 368473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.1    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 137      |
# |    time_elapsed    | 2713     |
# |    total_timesteps | 373374   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00301  |
# |    learning_rate   | 0.00253  |
# |    n_updates       | 373273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.3    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 137      |
# |    time_elapsed    | 2747     |
# |    total_timesteps | 378174   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00278  |
# |    learning_rate   | 0.00244  |
# |    n_updates       | 378073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.6    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 137      |
# |    time_elapsed    | 2783     |
# |    total_timesteps | 382974   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00246  |
# |    learning_rate   | 0.00234  |
# |    n_updates       | 382873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.8    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 137      |
# |    time_elapsed    | 2817     |
# |    total_timesteps | 387774   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00572  |
# |    learning_rate   | 0.00224  |
# |    n_updates       | 387673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.9    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 137      |
# |    time_elapsed    | 2852     |
# |    total_timesteps | 392574   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00378  |
# |    learning_rate   | 0.00215  |
# |    n_updates       | 392473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -26.6    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 137      |
# |    time_elapsed    | 2887     |
# |    total_timesteps | 397374   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00456  |
# |    learning_rate   | 0.00205  |
# |    n_updates       | 397273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 137      |
# |    time_elapsed    | 2921     |
# |    total_timesteps | 402174   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.0032   |
# |    learning_rate   | 0.00196  |
# |    n_updates       | 402073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -26.9    |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 137      |
# |    time_elapsed    | 2956     |
# |    total_timesteps | 406974   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 0.00697  |
# |    learning_rate   | 0.00186  |
# |    n_updates       | 406873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.5    |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 137      |
# |    time_elapsed    | 2991     |
# |    total_timesteps | 411774   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.00714  |
# |    learning_rate   | 0.00176  |
# |    n_updates       | 411673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.5    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 137      |
# |    time_elapsed    | 3026     |
# |    total_timesteps | 416574   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.0129   |
# |    learning_rate   | 0.00167  |
# |    n_updates       | 416473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.8    |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 137      |
# |    time_elapsed    | 3061     |
# |    total_timesteps | 421374   |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.00972  |
# |    learning_rate   | 0.00157  |
# |    n_updates       | 421273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.8    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 137      |
# |    time_elapsed    | 3096     |
# |    total_timesteps | 426174   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.0045   |
# |    learning_rate   | 0.00148  |
# |    n_updates       | 426073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.8    |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 137      |
# |    time_elapsed    | 3131     |
# |    total_timesteps | 430974   |
# | train/             |          |
# |    actor_loss      | 2.23     |
# |    critic_loss     | 0.0046   |
# |    learning_rate   | 0.00138  |
# |    n_updates       | 430873   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.7    |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 137      |
# |    time_elapsed    | 3165     |
# |    total_timesteps | 435774   |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.00446  |
# |    learning_rate   | 0.00128  |
# |    n_updates       | 435673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -28.6    |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 137      |
# |    time_elapsed    | 3202     |
# |    total_timesteps | 440574   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.00205  |
# |    learning_rate   | 0.00119  |
# |    n_updates       | 440473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.6    |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 137      |
# |    time_elapsed    | 3229     |
# |    total_timesteps | 444382   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.00237  |
# |    learning_rate   | 0.00111  |
# |    n_updates       | 444281   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.7    |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 137      |
# |    time_elapsed    | 3264     |
# |    total_timesteps | 449182   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.00434  |
# |    learning_rate   | 0.00102  |
# |    n_updates       | 449081   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.7    |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 137      |
# |    time_elapsed    | 3299     |
# |    total_timesteps | 453982   |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.00489  |
# |    learning_rate   | 0.00092  |
# |    n_updates       | 453881   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.3    |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 137      |
# |    time_elapsed    | 3334     |
# |    total_timesteps | 458782   |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 0.00884  |
# |    learning_rate   | 0.000824 |
# |    n_updates       | 458681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.5    |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 137      |
# |    time_elapsed    | 3368     |
# |    total_timesteps | 463582   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.00317  |
# |    learning_rate   | 0.000728 |
# |    n_updates       | 463481   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.7    |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 137      |
# |    time_elapsed    | 3403     |
# |    total_timesteps | 468382   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.00564  |
# |    learning_rate   | 0.000632 |
# |    n_updates       | 468281   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.8    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 137      |
# |    time_elapsed    | 3437     |
# |    total_timesteps | 473182   |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.00331  |
# |    learning_rate   | 0.000536 |
# |    n_updates       | 473081   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.9    |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 137      |
# |    time_elapsed    | 3472     |
# |    total_timesteps | 477982   |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.0101   |
# |    learning_rate   | 0.00044  |
# |    n_updates       | 477881   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.7    |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 137      |
# |    time_elapsed    | 3508     |
# |    total_timesteps | 482782   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00185  |
# |    learning_rate   | 0.000344 |
# |    n_updates       | 482681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -27.3    |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 137      |
# |    time_elapsed    | 3543     |
# |    total_timesteps | 487582   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00373  |
# |    learning_rate   | 0.000248 |
# |    n_updates       | 487481   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -26.9    |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 137      |
# |    time_elapsed    | 3578     |
# |    total_timesteps | 492382   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.00717  |
# |    learning_rate   | 0.000152 |
# |    n_updates       | 492281   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -26.9    |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 137      |
# |    time_elapsed    | 3612     |
# |    total_timesteps | 497182   |
# | train/             |          |
# |    actor_loss      | 2.16     |
# |    critic_loss     | 0.00911  |
# |    learning_rate   | 5.64e-05 |
# |    n_updates       | 497081   |
# ---------------------------------

# %%
## EXPERIMENT 2

def linear_schedule_up(final_value: float):
    """
    Linear learning rate schedule.The learning rate value will increase

    :param final_value: Final learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return (1-progress_remaining) * final_value

    return func

for i in range(EX_LOOP):
  if i > 0:
    del env
    del model_up
  # Initial learning rate of 0.001
  env = gym.make('VSS1vs1-v0')
  csv_name = f"log{i}_DDPG_up"
  env = stable_baselines3.common.monitor.Monitor(env,csv_name)
  env.reset()
  model_up = DDPG("MlpPolicy", env, learning_rate=linear_schedule_up(0.01), verbose=1)
  model_up.learn(total_timesteps=500_000)
# Out:
# Environment initialized
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -17.4    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 143      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -0.767   |
# |    critic_loss     | 0.00162  |
# |    learning_rate   | 9.6e-05  |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -12.1    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 142      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -1.76    |
# |    critic_loss     | 0.00284  |
# |    learning_rate   | 0.000192 |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -9.38    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 141      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -4.42    |
# |    critic_loss     | 0.00525  |
# |    learning_rate   | 0.000288 |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -9.24    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 141      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 19200    |
# | train/             |          |
# |    actor_loss      | -7.65    |
# |    critic_loss     | 0.0236   |
# |    learning_rate   | 0.000384 |
# |    n_updates       | 19099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -4.57    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 141      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 22854    |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.111    |
# |    learning_rate   | 0.000457 |
# |    n_updates       | 22753    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -2.56    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 141      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 27654    |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.0964   |
# |    learning_rate   | 0.000553 |
# |    n_updates       | 27553    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -4.66    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 140      |
# |    time_elapsed    | 231      |
# |    total_timesteps | 32454    |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 0.124    |
# |    learning_rate   | 0.000649 |
# |    n_updates       | 32353    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -7.11    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 140      |
# |    time_elapsed    | 263      |
# |    total_timesteps | 37090    |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 0.123    |
# |    learning_rate   | 0.000742 |
# |    n_updates       | 36989    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -2.89    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 140      |
# |    time_elapsed    | 289      |
# |    total_timesteps | 40729    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.208    |
# |    learning_rate   | 0.000815 |
# |    n_updates       | 40628    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -1.62    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 140      |
# |    time_elapsed    | 319      |
# |    total_timesteps | 44870    |
# | train/             |          |
# |    actor_loss      | -32      |
# |    critic_loss     | 0.336    |
# |    learning_rate   | 0.000897 |
# |    n_updates       | 44769    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -1.84    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 140      |
# |    time_elapsed    | 352      |
# |    total_timesteps | 49485    |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 0.394    |
# |    learning_rate   | 0.00099  |
# |    n_updates       | 49384    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -0.908   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 140      |
# |    time_elapsed    | 384      |
# |    total_timesteps | 53993    |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 0.396    |
# |    learning_rate   | 0.00108  |
# |    n_updates       | 53892    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -0.344   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 140      |
# |    time_elapsed    | 418      |
# |    total_timesteps | 58793    |
# | train/             |          |
# |    actor_loss      | -41.8    |
# |    critic_loss     | 0.489    |
# |    learning_rate   | 0.00118  |
# |    n_updates       | 58692    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -0.966   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 140      |
# |    time_elapsed    | 452      |
# |    total_timesteps | 63593    |
# | train/             |          |
# |    actor_loss      | -46.4    |
# |    critic_loss     | 0.494    |
# |    learning_rate   | 0.00127  |
# |    n_updates       | 63492    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 0.899    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 140      |
# |    time_elapsed    | 483      |
# |    total_timesteps | 67922    |
# | train/             |          |
# |    actor_loss      | -49.2    |
# |    critic_loss     | 0.685    |
# |    learning_rate   | 0.00136  |
# |    n_updates       | 67821    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -0.619   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 140      |
# |    time_elapsed    | 517      |
# |    total_timesteps | 72722    |
# | train/             |          |
# |    actor_loss      | -53.6    |
# |    critic_loss     | 0.685    |
# |    learning_rate   | 0.00145  |
# |    n_updates       | 72621    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 0.879    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 140      |
# |    time_elapsed    | 542      |
# |    total_timesteps | 76180    |
# | train/             |          |
# |    actor_loss      | -54.8    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.00152  |
# |    n_updates       | 76079    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 1.07     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 140      |
# |    time_elapsed    | 575      |
# |    total_timesteps | 80980    |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 0.854    |
# |    learning_rate   | 0.00162  |
# |    n_updates       | 80879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 0.312    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 140      |
# |    time_elapsed    | 609      |
# |    total_timesteps | 85780    |
# | train/             |          |
# |    actor_loss      | -57.2    |
# |    critic_loss     | 1.08     |
# |    learning_rate   | 0.00172  |
# |    n_updates       | 85679    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -0.742   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 140      |
# |    time_elapsed    | 644      |
# |    total_timesteps | 90580    |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 1.37     |
# |    learning_rate   | 0.00181  |
# |    n_updates       | 90479    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 140      |
# |    time_elapsed    | 678      |
# |    total_timesteps | 95380    |
# | train/             |          |
# |    actor_loss      | -55.7    |
# |    critic_loss     | 1.04     |
# |    learning_rate   | 0.00191  |
# |    n_updates       | 95279    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -1.79    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 140      |
# |    time_elapsed    | 712      |
# |    total_timesteps | 100180   |
# | train/             |          |
# |    actor_loss      | -54.3    |
# |    critic_loss     | 1.43     |
# |    learning_rate   | 0.002    |
# |    n_updates       | 100079   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -1.98    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 140      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 104980   |
# | train/             |          |
# |    actor_loss      | -50.4    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0021   |
# |    n_updates       | 104879   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -2.18    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 140      |
# |    time_elapsed    | 773      |
# |    total_timesteps | 108761   |
# | train/             |          |
# |    actor_loss      | -50      |
# |    critic_loss     | 0.952    |
# |    learning_rate   | 0.00218  |
# |    n_updates       | 108660   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -1.21    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 140      |
# |    time_elapsed    | 807      |
# |    total_timesteps | 113561   |
# | train/             |          |
# |    actor_loss      | -47.5    |
# |    critic_loss     | 0.75     |
# |    learning_rate   | 0.00227  |
# |    n_updates       | 113460   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 0.108    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 140      |
# |    time_elapsed    | 836      |
# |    total_timesteps | 117701   |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 0.692    |
# |    learning_rate   | 0.00235  |
# |    n_updates       | 117600   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 1.53     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 140      |
# |    time_elapsed    | 862      |
# |    total_timesteps | 121385   |
# | train/             |          |
# |    actor_loss      | -42.5    |
# |    critic_loss     | 0.786    |
# |    learning_rate   | 0.00243  |
# |    n_updates       | 121284   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 1.97     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 140      |
# |    time_elapsed    | 885      |
# |    total_timesteps | 124608   |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 0.713    |
# |    learning_rate   | 0.00249  |
# |    n_updates       | 124507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 1.17     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 140      |
# |    time_elapsed    | 920      |
# |    total_timesteps | 129408   |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 0.731    |
# |    learning_rate   | 0.00259  |
# |    n_updates       | 129307   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 0.517    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 140      |
# |    time_elapsed    | 954      |
# |    total_timesteps | 134208   |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 0.791    |
# |    learning_rate   | 0.00268  |
# |    n_updates       | 134107   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 0.413    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 140      |
# |    time_elapsed    | 974      |
# |    total_timesteps | 137047   |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 0.927    |
# |    learning_rate   | 0.00274  |
# |    n_updates       | 136946   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 0.968    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 140      |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 141847   |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 0.768    |
# |    learning_rate   | 0.00284  |
# |    n_updates       | 141746   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 3.28     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 140      |
# |    time_elapsed    | 1028     |
# |    total_timesteps | 144790   |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 4.65     |
# |    learning_rate   | 0.0029   |
# |    n_updates       | 144689   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 2.01     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 140      |
# |    time_elapsed    | 1063     |
# |    total_timesteps | 149590   |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 0.485    |
# |    learning_rate   | 0.00299  |
# |    n_updates       | 149489   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 3.18     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 140      |
# |    time_elapsed    | 1097     |
# |    total_timesteps | 154390   |
# | train/             |          |
# |    actor_loss      | -25.2    |
# |    critic_loss     | 0.799    |
# |    learning_rate   | 0.00309  |
# |    n_updates       | 154289   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 2.2      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 140      |
# |    time_elapsed    | 1131     |
# |    total_timesteps | 159190   |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 0.587    |
# |    learning_rate   | 0.00318  |
# |    n_updates       | 159089   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 1.3      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 140      |
# |    time_elapsed    | 1165     |
# |    total_timesteps | 163990   |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.587    |
# |    learning_rate   | 0.00328  |
# |    n_updates       | 163889   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 0.0408   |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 140      |
# |    time_elapsed    | 1194     |
# |    total_timesteps | 167998   |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 0.473    |
# |    learning_rate   | 0.00336  |
# |    n_updates       | 167897   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 0.844    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 140      |
# |    time_elapsed    | 1213     |
# |    total_timesteps | 170566   |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 0.391    |
# |    learning_rate   | 0.00341  |
# |    n_updates       | 170465   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 0.21     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 140      |
# |    time_elapsed    | 1244     |
# |    total_timesteps | 174797   |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.499    |
# |    learning_rate   | 0.0035   |
# |    n_updates       | 174696   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 1.3      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 140      |
# |    time_elapsed    | 1278     |
# |    total_timesteps | 179597   |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.4      |
# |    learning_rate   | 0.00359  |
# |    n_updates       | 179496   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 0.0419   |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 140      |
# |    time_elapsed    | 1310     |
# |    total_timesteps | 184045   |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.406    |
# |    learning_rate   | 0.00368  |
# |    n_updates       | 183944   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -1.28    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 140      |
# |    time_elapsed    | 1336     |
# |    total_timesteps | 187698   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.748    |
# |    learning_rate   | 0.00375  |
# |    n_updates       | 187597   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -0.336   |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 140      |
# |    time_elapsed    | 1370     |
# |    total_timesteps | 192498   |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.607    |
# |    learning_rate   | 0.00385  |
# |    n_updates       | 192397   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | -0.116   |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 140      |
# |    time_elapsed    | 1405     |
# |    total_timesteps | 197298   |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.534    |
# |    learning_rate   | 0.00395  |
# |    n_updates       | 197197   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 2.24     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 140      |
# |    time_elapsed    | 1433     |
# |    total_timesteps | 201324   |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.901    |
# |    learning_rate   | 0.00403  |
# |    n_updates       | 201223   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 3.37     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 140      |
# |    time_elapsed    | 1468     |
# |    total_timesteps | 206124   |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 0.964    |
# |    learning_rate   | 0.00412  |
# |    n_updates       | 206023   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 4.86     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 140      |
# |    time_elapsed    | 1485     |
# |    total_timesteps | 208579   |
# | train/             |          |
# |    actor_loss      | -9.72    |
# |    critic_loss     | 0.408    |
# |    learning_rate   | 0.00417  |
# |    n_updates       | 208478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 7.08     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 140      |
# |    time_elapsed    | 1513     |
# |    total_timesteps | 212404   |
# | train/             |          |
# |    actor_loss      | -9.37    |
# |    critic_loss     | 0.428    |
# |    learning_rate   | 0.00425  |
# |    n_updates       | 212303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 6.02     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 140      |
# |    time_elapsed    | 1536     |
# |    total_timesteps | 215613   |
# | train/             |          |
# |    actor_loss      | -9.77    |
# |    critic_loss     | 0.851    |
# |    learning_rate   | 0.00431  |
# |    n_updates       | 215512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 5.74     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 140      |
# |    time_elapsed    | 1570     |
# |    total_timesteps | 220413   |
# | train/             |          |
# |    actor_loss      | -8.02    |
# |    critic_loss     | 0.458    |
# |    learning_rate   | 0.00441  |
# |    n_updates       | 220312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 3.73     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 140      |
# |    time_elapsed    | 1604     |
# |    total_timesteps | 225213   |
# | train/             |          |
# |    actor_loss      | -7.27    |
# |    critic_loss     | 0.508    |
# |    learning_rate   | 0.0045   |
# |    n_updates       | 225112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 2.88     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 140      |
# |    time_elapsed    | 1639     |
# |    total_timesteps | 230013   |
# | train/             |          |
# |    actor_loss      | -6.13    |
# |    critic_loss     | 0.294    |
# |    learning_rate   | 0.0046   |
# |    n_updates       | 229912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 4.51     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 140      |
# |    time_elapsed    | 1664     |
# |    total_timesteps | 233510   |
# | train/             |          |
# |    actor_loss      | -5.87    |
# |    critic_loss     | 0.726    |
# |    learning_rate   | 0.00467  |
# |    n_updates       | 233409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 140      |
# |    time_elapsed    | 1698     |
# |    total_timesteps | 238310   |
# | train/             |          |
# |    actor_loss      | -4.64    |
# |    critic_loss     | 0.514    |
# |    learning_rate   | 0.00477  |
# |    n_updates       | 238209   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 4.93     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 140      |
# |    time_elapsed    | 1732     |
# |    total_timesteps | 243110   |
# | train/             |          |
# |    actor_loss      | -4.57    |
# |    critic_loss     | 0.509    |
# |    learning_rate   | 0.00486  |
# |    n_updates       | 243009   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 5.13     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 140      |
# |    time_elapsed    | 1767     |
# |    total_timesteps | 247910   |
# | train/             |          |
# |    actor_loss      | -4.84    |
# |    critic_loss     | 0.881    |
# |    learning_rate   | 0.00496  |
# |    n_updates       | 247809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 140      |
# |    time_elapsed    | 1801     |
# |    total_timesteps | 252710   |
# | train/             |          |
# |    actor_loss      | -5.12    |
# |    critic_loss     | 1.62     |
# |    learning_rate   | 0.00505  |
# |    n_updates       | 252609   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 4.46     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 140      |
# |    time_elapsed    | 1836     |
# |    total_timesteps | 257510   |
# | train/             |          |
# |    actor_loss      | -3.39    |
# |    critic_loss     | 0.769    |
# |    learning_rate   | 0.00515  |
# |    n_updates       | 257409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 1.82     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 140      |
# |    time_elapsed    | 1870     |
# |    total_timesteps | 262310   |
# | train/             |          |
# |    actor_loss      | -3.74    |
# |    critic_loss     | 0.684    |
# |    learning_rate   | 0.00525  |
# |    n_updates       | 262209   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 1.85     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 140      |
# |    time_elapsed    | 1905     |
# |    total_timesteps | 267110   |
# | train/             |          |
# |    actor_loss      | -2.55    |
# |    critic_loss     | 1.12     |
# |    learning_rate   | 0.00534  |
# |    n_updates       | 267009   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 2.43     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 140      |
# |    time_elapsed    | 1940     |
# |    total_timesteps | 271910   |
# | train/             |          |
# |    actor_loss      | -1.34    |
# |    critic_loss     | 0.718    |
# |    learning_rate   | 0.00544  |
# |    n_updates       | 271809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 2.73     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 139      |
# |    time_elapsed    | 1969     |
# |    total_timesteps | 275665   |
# | train/             |          |
# |    actor_loss      | -1.87    |
# |    critic_loss     | 0.481    |
# |    learning_rate   | 0.00551  |
# |    n_updates       | 275564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 1.22     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 139      |
# |    time_elapsed    | 2004     |
# |    total_timesteps | 280465   |
# | train/             |          |
# |    actor_loss      | -1.34    |
# |    critic_loss     | 0.486    |
# |    learning_rate   | 0.00561  |
# |    n_updates       | 280364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -0.0572  |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 139      |
# |    time_elapsed    | 2039     |
# |    total_timesteps | 285265   |
# | train/             |          |
# |    actor_loss      | -0.786   |
# |    critic_loss     | 0.557    |
# |    learning_rate   | 0.00571  |
# |    n_updates       | 285164   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | -1.22    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 139      |
# |    time_elapsed    | 2073     |
# |    total_timesteps | 290065   |
# | train/             |          |
# |    actor_loss      | -0.322   |
# |    critic_loss     | 0.371    |
# |    learning_rate   | 0.0058   |
# |    n_updates       | 289964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | -1.69    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 139      |
# |    time_elapsed    | 2107     |
# |    total_timesteps | 294865   |
# | train/             |          |
# |    actor_loss      | -0.314   |
# |    critic_loss     | 0.388    |
# |    learning_rate   | 0.0059   |
# |    n_updates       | 294764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -1.48    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 139      |
# |    time_elapsed    | 2142     |
# |    total_timesteps | 299665   |
# | train/             |          |
# |    actor_loss      | 0.117    |
# |    critic_loss     | 0.454    |
# |    learning_rate   | 0.00599  |
# |    n_updates       | 299564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 139      |
# |    time_elapsed    | 2176     |
# |    total_timesteps | 304465   |
# | train/             |          |
# |    actor_loss      | 0.0994   |
# |    critic_loss     | 0.904    |
# |    learning_rate   | 0.00609  |
# |    n_updates       | 304364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -3.27    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 139      |
# |    time_elapsed    | 2210     |
# |    total_timesteps | 309265   |
# | train/             |          |
# |    actor_loss      | 1.16     |
# |    critic_loss     | 1.33     |
# |    learning_rate   | 0.00619  |
# |    n_updates       | 309164   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -5.73    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 139      |
# |    time_elapsed    | 2244     |
# |    total_timesteps | 314065   |
# | train/             |          |
# |    actor_loss      | 0.982    |
# |    critic_loss     | 0.243    |
# |    learning_rate   | 0.00628  |
# |    n_updates       | 313964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -7.47    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 139      |
# |    time_elapsed    | 2278     |
# |    total_timesteps | 318865   |
# | train/             |          |
# |    actor_loss      | 0.37     |
# |    critic_loss     | 0.208    |
# |    learning_rate   | 0.00638  |
# |    n_updates       | 318764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -9.81    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 139      |
# |    time_elapsed    | 2313     |
# |    total_timesteps | 323665   |
# | train/             |          |
# |    actor_loss      | 0.778    |
# |    critic_loss     | 0.753    |
# |    learning_rate   | 0.00647  |
# |    n_updates       | 323564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -12.7    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 139      |
# |    time_elapsed    | 2348     |
# |    total_timesteps | 328465   |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.636    |
# |    learning_rate   | 0.00657  |
# |    n_updates       | 328364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -13.7    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 139      |
# |    time_elapsed    | 2382     |
# |    total_timesteps | 333265   |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.442    |
# |    learning_rate   | 0.00667  |
# |    n_updates       | 333164   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -14.9    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 139      |
# |    time_elapsed    | 2417     |
# |    total_timesteps | 338065   |
# | train/             |          |
# |    actor_loss      | 2.12     |
# |    critic_loss     | 0.343    |
# |    learning_rate   | 0.00676  |
# |    n_updates       | 337964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -15.2    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 139      |
# |    time_elapsed    | 2451     |
# |    total_timesteps | 342865   |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.165    |
# |    learning_rate   | 0.00686  |
# |    n_updates       | 342764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -14.6    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 139      |
# |    time_elapsed    | 2477     |
# |    total_timesteps | 346539   |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 0.358    |
# |    learning_rate   | 0.00693  |
# |    n_updates       | 346438   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -16.4    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 139      |
# |    time_elapsed    | 2512     |
# |    total_timesteps | 351339   |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.292    |
# |    learning_rate   | 0.00703  |
# |    n_updates       | 351238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -17.6    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 139      |
# |    time_elapsed    | 2548     |
# |    total_timesteps | 356139   |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.292    |
# |    learning_rate   | 0.00712  |
# |    n_updates       | 356038   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -19.5    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 139      |
# |    time_elapsed    | 2583     |
# |    total_timesteps | 360939   |
# | train/             |          |
# |    actor_loss      | 1.25     |
# |    critic_loss     | 0.42     |
# |    learning_rate   | 0.00722  |
# |    n_updates       | 360838   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -20.5    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 139      |
# |    time_elapsed    | 2617     |
# |    total_timesteps | 365739   |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.465    |
# |    learning_rate   | 0.00731  |
# |    n_updates       | 365638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -22.4    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 139      |
# |    time_elapsed    | 2652     |
# |    total_timesteps | 370539   |
# | train/             |          |
# |    actor_loss      | 2.68     |
# |    critic_loss     | 0.991    |
# |    learning_rate   | 0.00741  |
# |    n_updates       | 370438   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -23.3    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 139      |
# |    time_elapsed    | 2689     |
# |    total_timesteps | 375339   |
# | train/             |          |
# |    actor_loss      | 2.51     |
# |    critic_loss     | 0.813    |
# |    learning_rate   | 0.00751  |
# |    n_updates       | 375238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -23.8    |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 139      |
# |    time_elapsed    | 2724     |
# |    total_timesteps | 380139   |
# | train/             |          |
# |    actor_loss      | 2.47     |
# |    critic_loss     | 1.48     |
# |    learning_rate   | 0.0076   |
# |    n_updates       | 380038   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -23.5    |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 139      |
# |    time_elapsed    | 2758     |
# |    total_timesteps | 384939   |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.443    |
# |    learning_rate   | 0.0077   |
# |    n_updates       | 384838   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.2    |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 139      |
# |    time_elapsed    | 2793     |
# |    total_timesteps | 389739   |
# | train/             |          |
# |    actor_loss      | 2.26     |
# |    critic_loss     | 0.282    |
# |    learning_rate   | 0.00779  |
# |    n_updates       | 389638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 139      |
# |    time_elapsed    | 2827     |
# |    total_timesteps | 394539   |
# | train/             |          |
# |    actor_loss      | 2.45     |
# |    critic_loss     | 0.43     |
# |    learning_rate   | 0.00789  |
# |    n_updates       | 394438   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 139      |
# |    time_elapsed    | 2862     |
# |    total_timesteps | 399339   |
# | train/             |          |
# |    actor_loss      | 2.22     |
# |    critic_loss     | 0.358    |
# |    learning_rate   | 0.00799  |
# |    n_updates       | 399238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 139      |
# |    time_elapsed    | 2898     |
# |    total_timesteps | 404139   |
# | train/             |          |
# |    actor_loss      | 1.74     |
# |    critic_loss     | 0.211    |
# |    learning_rate   | 0.00808  |
# |    n_updates       | 404038   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.4    |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 139      |
# |    time_elapsed    | 2926     |
# |    total_timesteps | 408071   |
# | train/             |          |
# |    actor_loss      | 0.914    |
# |    critic_loss     | 0.215    |
# |    learning_rate   | 0.00816  |
# |    n_updates       | 407970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.8    |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 139      |
# |    time_elapsed    | 2954     |
# |    total_timesteps | 411967   |
# | train/             |          |
# |    actor_loss      | 0.988    |
# |    critic_loss     | 0.298    |
# |    learning_rate   | 0.00824  |
# |    n_updates       | 411866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.7    |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 139      |
# |    time_elapsed    | 2990     |
# |    total_timesteps | 416767   |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.627    |
# |    learning_rate   | 0.00834  |
# |    n_updates       | 416666   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 139      |
# |    time_elapsed    | 3025     |
# |    total_timesteps | 421567   |
# | train/             |          |
# |    actor_loss      | 0.972    |
# |    critic_loss     | 0.482    |
# |    learning_rate   | 0.00843  |
# |    n_updates       | 421466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 139      |
# |    time_elapsed    | 3060     |
# |    total_timesteps | 426367   |
# | train/             |          |
# |    actor_loss      | 0.655    |
# |    critic_loss     | 0.339    |
# |    learning_rate   | 0.00853  |
# |    n_updates       | 426266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.6    |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 139      |
# |    time_elapsed    | 3094     |
# |    total_timesteps | 431167   |
# | train/             |          |
# |    actor_loss      | 0.924    |
# |    critic_loss     | 0.619    |
# |    learning_rate   | 0.00862  |
# |    n_updates       | 431066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.7    |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 139      |
# |    time_elapsed    | 3128     |
# |    total_timesteps | 435967   |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.628    |
# |    learning_rate   | 0.00872  |
# |    n_updates       | 435866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 139      |
# |    time_elapsed    | 3163     |
# |    total_timesteps | 440767   |
# | train/             |          |
# |    actor_loss      | 1.1      |
# |    critic_loss     | 0.225    |
# |    learning_rate   | 0.00882  |
# |    n_updates       | 440666   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.1    |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 139      |
# |    time_elapsed    | 3197     |
# |    total_timesteps | 445567   |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.327    |
# |    learning_rate   | 0.00891  |
# |    n_updates       | 445466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.2    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 139      |
# |    time_elapsed    | 3231     |
# |    total_timesteps | 450367   |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.186    |
# |    learning_rate   | 0.00901  |
# |    n_updates       | 450266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 139      |
# |    time_elapsed    | 3265     |
# |    total_timesteps | 455167   |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.154    |
# |    learning_rate   | 0.0091   |
# |    n_updates       | 455066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -25.3    |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 139      |
# |    time_elapsed    | 3299     |
# |    total_timesteps | 459967   |
# | train/             |          |
# |    actor_loss      | 1.86     |
# |    critic_loss     | 0.241    |
# |    learning_rate   | 0.0092   |
# |    n_updates       | 459866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -26.1    |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 139      |
# |    time_elapsed    | 3333     |
# |    total_timesteps | 464767   |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.143    |
# |    learning_rate   | 0.0093   |
# |    n_updates       | 464666   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.8    |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 139      |
# |    time_elapsed    | 3367     |
# |    total_timesteps | 469567   |
# | train/             |          |
# |    actor_loss      | 0.999    |
# |    critic_loss     | 0.169    |
# |    learning_rate   | 0.00939  |
# |    n_updates       | 469466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 139      |
# |    time_elapsed    | 3401     |
# |    total_timesteps | 474367   |
# | train/             |          |
# |    actor_loss      | 1.25     |
# |    critic_loss     | 0.0903   |
# |    learning_rate   | 0.00949  |
# |    n_updates       | 474266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.4    |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 139      |
# |    time_elapsed    | 3434     |
# |    total_timesteps | 479167   |
# | train/             |          |
# |    actor_loss      | 1.14     |
# |    critic_loss     | 0.158    |
# |    learning_rate   | 0.00958  |
# |    n_updates       | 479066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 139      |
# |    time_elapsed    | 3469     |
# |    total_timesteps | 483967   |
# | train/             |          |
# |    actor_loss      | 1.16     |
# |    critic_loss     | 0.221    |
# |    learning_rate   | 0.00968  |
# |    n_updates       | 483866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 139      |
# |    time_elapsed    | 3502     |
# |    total_timesteps | 488767   |
# | train/             |          |
# |    actor_loss      | 1.23     |
# |    critic_loss     | 0.106    |
# |    learning_rate   | 0.00978  |
# |    n_updates       | 488666   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 139      |
# |    time_elapsed    | 3536     |
# |    total_timesteps | 493567   |
# | train/             |          |
# |    actor_loss      | 0.989    |
# |    critic_loss     | 0.127    |
# |    learning_rate   | 0.00987  |
# |    n_updates       | 493466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | -23.2    |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 139      |
# |    time_elapsed    | 3563     |
# |    total_timesteps | 497367   |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.0278   |
# |    learning_rate   | 0.00995  |
# |    n_updates       | 497266   |
# ---------------------------------

# %% [markdown]
# # Mostrar gráficas archivos CSV
# Por último, se crean las gráficas que representan la evolución media de las recompensas a lo largo de los valores de *learning rate* a partir de los archivos CSV que se han guardado gracias al *wrapper* Monitor que se ha instanciado.
#
# Habra dos gráficas, una representará la evolución de las recompensas para el caso en el que la tasa de aprendizaje es ascendente y otra para cuando el valor de dicha tasa va descendiendo. Esta distinción es debida a que en los primeros momentos en los que el algoritmo se va ejecutando este realmente no mejora su comportamiento de forma muy notable porque todavía está aprendiendo. Esto hace que el verdadero impacto del valor de la tasa de aprendizaje se aprecie más en las iteraciones más cercanas al final del entrenamiento y por ello se ha querido que todos los valores de la tasa de aprendizaje que se querían testear se alojaran en la parte final del entrenamiento.
#
# Además, se ha hecho una normalización de los valores de recompensa dividiendo todos los valores de cada uno de los archivos CSV entre el valor máximo de dicho archivo para mitigar el efecto que tiene el hecho de empezar con una recompensa muy alta o muy baja(puesto que es algo aleatorio).

# %%
import os
from google.colab import drive
import csv
import numpy as np
import matplotlib.pyplot as plt


def norm_vector(vec):
  positive_vec = vec + abs(np.min(vec))
  norm_vec = positive_vec * 100 / np.max(positive_vec)
  return norm_vec


def calculate_media_std(vec1, vec2, vec3):
  final_array = []
  vec1 = norm_vector(vec1)
  vec2 = norm_vector(vec2)
  vec3 = norm_vector(vec3)

  for v1,v2,v3 in zip(vec1,vec2,vec3):
    final_array.append((v1+v2+v3)/3)
    final_array.append(np.std([v1,v2,v3]))

  return np.array(final_array).reshape(vec1.size, 2)


# Path to the folder containing csv files
FOLDER_PATH = "./drive/MyDrive/Colab Notebooks/TFG/Entrenamiento en rSoccer/Entorno simulado/Fase 1 Ajuste de hiperparámetros"

# Path to csv files
CSV_DOWN_0 = os.path.join(FOLDER_PATH, "log0_DDPG_down.monitor.csv")
CSV_DOWN_1 = os.path.join(FOLDER_PATH, "log1_DDPG_down.monitor.csv")
CSV_DOWN_2 = os.path.join(FOLDER_PATH, "log2_DDPG_down.monitor.csv")
CSV_UP_0 = os.path.join(FOLDER_PATH, "log0_DDPG_up.monitor.csv")
CSV_UP_1 = os.path.join(FOLDER_PATH, "log1_DDPG_up.monitor.csv")
CSV_UP_2 = os.path.join(FOLDER_PATH, "log2_DDPG_up.monitor.csv")

# Create a local directory to access my files stored in google drive
drive.mount("./drive")

# Create empty lists to fill them with rewards values of csv files and
# convert them to numpy arrays
reward_down_0 = []
reward_down_1 = []
reward_down_2 = []
with open(CSV_DOWN_0,"r") as csv0, open(CSV_DOWN_1,"r") as csv1, open(CSV_DOWN_2,"r") as csv2:
  csv0_read = csv.reader(csv0)
  csv1_read = csv.reader(csv1)
  csv2_read = csv.reader(csv2)
  next(csv0_read)
  next(csv1_read)
  next(csv2_read)
  for rows0, rows1, rows2 in zip(csv0_read, csv1_read, csv2_read):
    reward_down_0.append(float(rows0[0]))
    reward_down_1.append(float(rows1[0]))
    reward_down_2.append(float(rows2[0]))

reward_up_0 = []
reward_up_1 = []
reward_up_2 = []
with open(CSV_UP_0,"r") as csv0, open(CSV_UP_1,"r") as csv1, open(CSV_UP_2,"r") as csv2:
  csv0_read = csv.reader(csv0)
  csv1_read = csv.reader(csv1)
  csv2_read = csv.reader(csv2)
  next(csv0_read)
  next(csv1_read)
  next(csv2_read)
  for rows0, rows1, rows2 in zip(csv0_read, csv1_read, csv2_read):
    reward_up_0.append(float(rows0[0]))
    reward_up_1.append(float(rows1[0]))
    reward_up_2.append(float(rows2[0]))

reward_down_0 = np.array(reward_down_0)
reward_down_1 = np.array(reward_down_1)
reward_down_2 = np.array(reward_down_2)
reward_up_0 = np.array(reward_up_0)
reward_up_1 = np.array(reward_up_1)
reward_up_2 = np.array(reward_up_2)

# Create two arrays that represent the average values of 0, 1 and 2 arrays
norm_reward_down = calculate_media_std(reward_down_0, reward_down_1, reward_down_2)
norm_reward_up = calculate_media_std(reward_up_0, reward_up_1, reward_up_2)

# Create two arrays that represent the learning rate values
lr_down = np.linspace(0.01, 1e-5, num=422)
lr_up = np.linspace(1e-5, 0.01, num=430)

# Plot graphs
figure, axis = plt.subplots(1,2)

axis[0].set_title("Learning Rate Schedule down")
axis[0].plot(lr_down, norm_reward_down[:,0])
axis[0].fill_between(
    lr_down,
    norm_reward_down[:,0]-norm_reward_down[:,1],
    norm_reward_down[:,0]+norm_reward_down[:,1],
    color="green"
)

axis[1].set_title("Learning Rate Schedule up")
axis[1].plot(lr_up, norm_reward_up[:,0])
axis[1].fill_between(
    lr_up,
    norm_reward_up[:,0]-norm_reward_up[:,1],
    norm_reward_up[:,0]+norm_reward_up[:,1],
    color="green"
)

plt.show()
# Out:
# Drive already mounted at ./drive; to attempt to forcibly remount, call drive.mount("./drive", force_remount=True).

# %% [markdown]
# Para estas dos gráficas cada una tiene una zona de mayor interés que es la que se va a analizar:
#
# *   Learning Rate Schedule down: En este caso la zona de interés es la que va desde el principio hasta la mitad porque son los últimos valores del *learning rate*
# *   Learning Rate Schedule up: En este caso la zona de interés es la que va desde la mitad hasta el final porque son los últimos valores del *learning rate*
#
# Como se puede observar en la gráfica de la derecha, los valores más cercanos al 0,01 producen una disminución de la recompensa, esto puede ser debido a que un valor de la tasa de aprendizaje demasiado alto produce oscilaciones en vez de converger hacia una mejor aproximación en el caso de las redes neuronales.
#
# En mi opinión, viendo la gráfica de la izquierda creo que **el valor óptimo del *learning rate* sería de 6,25e-4** aproximadamente ya que es donde se experimenta una mayor subida del valor medio de la recompensa.
